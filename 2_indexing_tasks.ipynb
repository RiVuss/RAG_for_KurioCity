# %%
import json
from qdrant_client import QdrantClient
from qdrant_client.http.models import VectorParams, Distance
from tqdm import tqdm
from httpx import ReadTimeout
import time
from sentence_transformers import SentenceTransformer

# %% [markdown]
# # Qdrat

# %% [markdown]
# ## all-MiniLM-L6-v2_embeddings.json

# %%
# 1. Load the JSON File
with open('embeddings/all-MiniLM-L6-v2_embeddings.json', 'r') as f:
    data = json.load(f)

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import time
from httpx import ReadTimeout

# 2. Initialize Qdrant Client
client = QdrantClient(host="localhost", port=6333)

# 3. Create Collection in Qdrant
collection_name = "all-MiniLM-L6-v2_collection"
vector_dim = len(data[0]['embedding'])  # Dimension of the embeddings

client.recreate_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=vector_dim, distance=Distance.COSINE),
)


def upload_batch(client, collection_name, points, batch_index, total_batches, retries=3):
    """Uploads a single batch to Qdrant with retry logic."""
    for attempt in range(retries):
        try:
            client.upsert(collection_name=collection_name, points=points)
            return True  # Upload successful
        except ReadTimeout:
            print(f"Timeout for batch {batch_index}/{total_batches}. Retrying ({attempt + 1}/{retries})...")
            time.sleep(2)  # Wait before retrying
    print(f"Failed to upload batch {batch_index}/{total_batches} after {retries} attempts.")
    return False  # Upload failed after retries


def upload_to_qdrant(data, collection_name, client, batch_size=50, max_workers=8):
    """Uploads data to Qdrant in parallel using multiple threads."""
    num_batches = (len(data) + batch_size - 1) // batch_size  # Total number of batches
    batches = [
        data[i:i + batch_size]
        for i in range(0, len(data), batch_size)
    ]
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        with tqdm(total=num_batches, desc="Uploading to Qdrant") as pbar:
            for batch_index, batch in enumerate(batches, start=1):
                points = [
                    {
                        "id": item["id"],
                        "vector": item["embedding"],
                        "payload": item["metadata"],
                    }
                    for item in batch
                ]
                # Submit each batch upload task to the executor
                futures.append(
                    executor.submit(upload_batch, client, collection_name, points, batch_index, num_batches)
                )
            
            # Process completed tasks and update the progress bar
            for future in as_completed(futures):
                pbar.update(1)  # Increment progress bar for each completed task
                if not future.result():
                    print("A batch failed to upload.")
    
    print(f"Data uploaded to Qdrant collection: {collection_name}")


# Upload embeddings to Qdrant using parallel threads
upload_to_qdrant(data, collection_name, client, batch_size=50, max_workers=4)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_4464\3550836263.py:13: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Uploading to Qdrant: 100%|██████████| 803/803 [06:53<00:00,  1.94it/s]
# Data uploaded to Qdrant collection: all-MiniLM-L6-v2_collection

# %%
# Initialize the embedding model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Function to Query Qdrant with Text
def query_qdrant_with_text(client, collection_name, query_text, top_k=3):
    # Step 1: Convert query text to a vector
    query_vector = model.encode(query_text)

    # Step 2: Search the Qdrant collection
    search_result = client.search(
        collection_name=collection_name,
        query_vector=query_vector,
        limit=top_k,
    )

    # Step 3: Return search results
    return search_result

# Example Usage
query_text = "cool architecture in Amsterdam"
results = query_qdrant_with_text(client, collection_name, query_text, top_k=15)

# Display Results
print(f"Query: {query_text}\n")
for result in results:
    print(f"Result ID: {result.id}, Score: {result.score}")
    print(f"Metadata: {result.payload['title'],result.payload['main_category']}\n")
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_4464\3771548022.py:10: DeprecationWarning: `search` method is deprecated and will be removed in the future. Use `query_points` instead.
#   search_result = client.search(
# Query: cool architecture in Amsterdam
#
# Result ID: 4823183, Score: 0.7274457
# Metadata: ('Lijnbaansgracht 18A-C', 'building')
#
# Result ID: 5395888, Score: 0.70786786
# Metadata: ('Nieuwe Looiersstraat 68-70', 'building')
#
# Result ID: 2287299, Score: 0.7032949
# Metadata: ('Huize Sint-Jan', 'monument')
#
# Result ID: 5433672, Score: 0.69894695
# Metadata: ('De Scheppende Hand & Chaos', 'statue')
#
# Result ID: 3838800, Score: 0.6983609
# Metadata: ('Marisstraat', 'street')
#
# Result ID: 3838806, Score: 0.688607
# Metadata: ('Mesdagplein', 'square')
#
# Result ID: 3843778, Score: 0.6884556
# Metadata: ('Turfstraat 28a-32 (Baarn)', 'building')
#
# Result ID: 4818690, Score: 0.68700856
# Metadata: ('Paviljoen Noorderplantsoen', 'building')
#
# Result ID: 5226629, Score: 0.68608326
# Metadata: ('Memories (Bastardilla)', 'street art')
#
# Result ID: 1375486, Score: 0.685442
# Metadata: ('Kruiskerk van Delfzijl', 'church')
#
# Result ID: 5679631, Score: 0.68539655
# Metadata: ('Lycka', 'building')
#
# Result ID: 5641956, Score: 0.68520623
# Metadata: ('Rijksmonument 335369', 'monument')
#
# Result ID: 1821257, Score: 0.682288
# Metadata: ('Voormalige bibliotheek (Bussum)', 'building')
#
# Result ID: 5710498, Score: 0.68167746
# Metadata: ('Haarlemmerstraat 83 (Amsterdam)', 'building')
#
# Result ID: 1660110, Score: 0.67991066
# Metadata: ('De Piramides', 'unique architecture')

# %%
import folium
from IPython.display import display

def display_map_inline(results):
    # Initialize a map centered around the first result's coordinates
    first_location = results[0].payload
    map_center = [first_location['latitude'], first_location['longitude']]
    map_object = folium.Map(location=map_center, zoom_start=12)

    # Add markers for each result
    for result in results:
        metadata = result.payload
        title = metadata.get('title', 'Unknown')
        latitude = metadata['latitude']
        longitude = metadata['longitude']
        main_category = metadata.get('main_category', 'N/A')
        subcategories = metadata.get('subcategories', 'N/A')

        # Add a marker with a popup
        popup_content = f"<b>{title}</b><br>Main Category: {main_category}<br>Subcategories: {subcategories}"
        folium.Marker(
            location=[latitude, longitude],
            popup=popup_content,
            tooltip=title,
        ).add_to(map_object)

    # Display the map directly in the notebook
    display(map_object)
    return map_object

# Example: Generate and display map
#map_object = display_map_inline(results)

# %% [markdown]
# # FAISS
# Trying FAISS if it is easier to use
#
# ## all-MiniLM-L6-v2

# %%
import json
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer

# %%
# Load embeddings from JSON file
embeddings_file = "embeddings/all-MiniLM-L6-v2_embeddings.json"
with open(embeddings_file, "r") as f:
    embeddings_data = json.load(f)

# Extract embeddings and IDs
embeddings = np.array([item["embedding"] for item in embeddings_data], dtype="float32")
ids = [item["id"] for item in embeddings_data]

# Load the metadata DataFrame
metadata_file = "nl_full_all_columns.csv"
metadata_df = pd.read_csv(metadata_file)

filtered_metadata_df = metadata_df[metadata_df["id"].isin(ids)].set_index("id")

# %%
# Normalize embeddings for cosine similarity
def normalize(vectors):
    norms = np.linalg.norm(vectors, axis=1, keepdims=True)
    return vectors / norms

embeddings_normalized = normalize(embeddings)

# Create a FAISS index for cosine similarity
dimension = embeddings_normalized.shape[1]  # Size of embedding vectors
index = faiss.IndexFlatIP(dimension)  # Inner product for cosine similarity
index.add(embeddings_normalized)

# Save the index to disk (optional)
faiss.write_index(index, "embeddings/all-MiniLM-L6-v2_faiss_index.index")

# %%
def query_faiss(index, query_text, model, metadata_df, ids, top_k=5):
    """
    Query the FAISS index and retrieve limited metadata.

    Args:
        index: FAISS index instance.
        query_text: Text query for similarity search.
        model: SentenceTransformer instance for generating query embeddings.
        metadata_df: Pandas DataFrame containing metadata indexed by ID.
        ids: List of IDs corresponding to embeddings.
        top_k: Number of top results to retrieve.

    Returns:
        List of results containing ID, score, and selected metadata fields.
    """
    # Step 1: Convert query text to vector
    query_vector = model.encode([query_text]).astype("float32")
    query_vector = query_vector / np.linalg.norm(query_vector, axis=1, keepdims=True)  # Normalize for cosine similarity

    # Step 2: Search FAISS index
    distances, indices = index.search(query_vector, top_k)

    # Step 3: Retrieve limited metadata for results
    results = []
    for idx, dist in zip(indices[0], distances[0]):
        if idx == -1:  # No result
            continue
        result_id = ids[idx]
        metadata_row = metadata_df.loc[result_id]
        metadata = {
            "title": metadata_row["title"],
            "main_category": metadata_row["main_category"],
            "subcategories": metadata_row["subcategories"],
            "latitude": metadata_row["latitude"],
            "longitude": metadata_row["longitude"],
            "generated_text": metadata_row["generated_text"],
        }
        results.append({
            "id": result_id,
            "score": dist,
            "metadata": metadata,
        })
    return results

# %%
# Load the Sentence Transformer model
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")



# Example Query
query_text = "modern architecture in Rotterdam"
top_k = 8
results = query_faiss(index, query_text, model, filtered_metadata_df, ids, top_k)

# Display Results
print(f"Query: {query_text}\n")
for result in results:
    print(f"Result ID: {result['id']}, Score: {result['score']}")
    print(f"Metadata: {result['metadata']}\n")
# Out:
# Query: modern architecture in Rotterdam
#
# Result ID: 5134637, Score: 0.7322934865951538
# Metadata: {'title': 'Up:Town', 'main_category': 'skyscraper', 'subcategories': 'unique architecture, city', 'latitude': np.float64(51.916575), 'longitude': np.float64(4.486402777777778), 'generated_text': "Let's explore the Up:Town building, a striking addition to Rotterdam's skyline.  Standing at 107 meters tall, it's a significant structure on the Wijnhaveneiland.  Completed in late 2018,  this impressive building boasts 34 floors, housing a mix of rental and ownership apartments.  The top eight floors offer luxury apartments for purchase, while the rest are available for rent, providing a variety of living options within this modern high-rise.  Its design seamlessly blends residential space with the vibrant urban environment of Rotterdam. The building is a true testament to modern architecture, and contributes significantly to Rotterdam's ever-evolving cityscape.\n"}
#
# Result ID: 459691, Score: 0.7214897871017456
# Metadata: {'title': 'Rotterdam Centrum', 'main_category': 'city', 'subcategories': 'region, unique architecture', 'latitude': np.float64(51.91793055555555), 'longitude': np.float64(4.477872222222223), 'generated_text': "Rotterdam Centrum: A City Reborn\n\nLet's explore the heart of Rotterdam, a city dramatically reshaped by its history.  Its current form is the result of several key events.  Firstly, the city's historical development, culminating in the creation of the Stadsdriehoek, a significant triangular area.  Secondly, the ambitious Water Project, including the construction of the Westersingel canal, significantly altered the city's landscape. Then, the devastating bombing of 1940, which destroyed most of the historic city center, fundamentally changed its fate. The subsequent reconstruction, guided by the Master Plan for Reconstruction, shaped the city's urban development until the 1970s. Finally, the rise of high-rise buildings from the 1980s onward contributed to the modern skyline.\n\nThis remarkable transformation is evident throughout the city center.  You'll recognize iconic landmarks such as the Euromast, offering panoramic views; the Beurstraverse and its Koopgoot shopping arcade, alongside the Beurs World Trade Center; the Lijnbaan pedestrian shopping street; the Coolsingel, home to the city hall and Hofplein; and of course, the impressive Erasmus Bridge and Willems Bridge.  Don't miss the Grote of Sint-Laurenskerk, one of the few surviving historical buildings, the impressive Central Station, the unique Cube Houses, the Markthal food market, and the Schielandshuis museum, offering fascinating insights into Rotterdam’s history.  And of course, the Rotterdam Metro, offering easy access to all parts of the city.\n\nThe city centre is divided into several distinct neighbourhoods, each with its own character: the Oude Westen, the Stadsdriehoek, Cool, the CS-kwartier, Nieuwe Werk (also known as the Scheepvaartkwartier), and Dijkzigt. Each area offers a unique glimpse into the city’s vibrant culture.\n\nRotterdam Centrum enjoys excellent public transport links. It’s easily accessible by metro, tram, bus, and train, with several stations strategically located throughout the city centre, making exploration simple and enjoyable.\n"}
#
# Result ID: 4817753, Score: 0.7109606266021729
# Metadata: {'title': 'Blaak 10', 'main_category': 'building', 'subcategories': 'unique architecture, monument', 'latitude': np.float64(51.91861111111111), 'longitude': np.float64(4.488888888888889), 'generated_text': "This building at 10 Blaak, in the heart of Rotterdam, is a national monument, a former bank building, and currently houses the Willem de Kooning Academy.  It's a fascinating example of architectural history.\n\nConstruction took place between 1930 and 1934 for the R. Mees & Zoonen bank. Architects A.J. Kropholler and A.A. Nieuwenhuijzen designed it in a traditional style.  The project was a significant renovation. Two existing buildings were incorporated into a new structure with a concrete skeleton. Interestingly, a corner building designed by Ph. van Uden, featuring a sculpture of William II, was integrated into the design.\n\nThe building suffered considerable damage during the Second World War, but was successfully restored after the conflict. Since 1981, it's served as a home for the art academy.\n\nArchitecturally, it's a large building, partly three and partly four stories high, including a basement.  Three wings are grouped around a trapezoidal courtyard. High gabled roofs, covered in red tiles, crown the wings, with corner gables featuring chimneys topped with cast iron caps.  Notice the concrete skeleton supporting the building's structure. The facades, above a natural stone base, are made from large red bricks, complemented by natural stone lintels, sills, keystones, and surrounds. Steel window frames are used throughout with a variety of pane arrangements. The wings are topped by overhanging eaves supported by natural stone consoles.\n\nThe main facade on Blaak Street is relatively closed, with small rectangular windows under heavy lintels.  A central arched entrance features a natural stone staircase and heavy bronze doors framed by large natural stone blocks. Above the portal, you'll find a round window with a star-shaped pattern.  The building offers a nice variety in windows sizes,  arranged in different ways on each floor and facade. The east facade features large steel windows, and a gable end. The facade along Wijnstraat also has a gable end, next to a tower-like staircase with battlements. The rear facade has larger rectangular windows on the ground and first floor and smaller ones on the second floor, with two dormers in the roof. A rounded corner at the intersection of Vissteeg and Wijnstraat contains a niche with a statue of King William II, sculpted by J.Th. Stracké in 1849.  The corner of Blaak and Vissteeg is chamfered on the ground floor and finished with natural stone blocks.\n\nInside, the building holds further architectural interest. A noteworthy feature is the impressive natural stone hall with elaborate sculptures, topped by a glass roof – a remnant from the original 1904-1906 building, designed by Christiaan Posthumus Meyjes Jr.  There's also a massive vault in the basement.\n\nThis building’s value extends beyond its aesthetics.  Its traditional style, dating back to 1930-1934, holds significant architectural and cultural historical value, as well as urban planning value. Its place within the oeuvre of architect Kropholler further enhances its importance.\n"}
#
# Result ID: 5107612, Score: 0.7093216180801392
# Metadata: {'title': 'Elevatorhuis', 'main_category': 'building', 'subcategories': 'unique architecture, art', 'latitude': np.float64(51.907688888888885), 'longitude': np.float64(4.476897222222222), 'generated_text': "This building, known as the Elevator House, is a fascinating example of Rotterdam architecture.  Commissioned by the Grain Elevator Company, it was designed by architect Michiel Brinkman. The building's exterior is striking. Notice the tiled panel by Rotterdam artist Bernard Richters at the top of the facade.  It beautifully depicts a ship being unloaded by steam cranes, a clear reference to the building's original function. The symmetrical facade, with its classicist design, features a main entrance on the right. The building's foundation is of natural stone, while the rest of the exterior is brick with a crown molding and a hipped roof.\n\nStepping inside, you'll find a magnificent central hall dominated by a monumental staircase and a stunning stained-glass skylight designed by Jan Schouten. Spacious offices flank the front and rear of the building.  The boardroom and the director's office, located at the rear on the first floor, are particularly impressive.  Finished with oak and rosewood paneling, the boardroom once featured stained-glass windows depicting scenes from the company's history. In contrast, the offices for the employees were more modestly appointed. For its time, the building boasted modern conveniences such as a lift and central heating.  Interestingly, the second floor, accessible via a separate lift and staircase, served as residential space until 1976. The building has had a long history, including extensive use as a bank.  Recently, around 2020, Broek Bakema Architects undertook a meticulous renovation, restoring many original details and achieving an impressive energy label A.  The restoration beautifully preserves this significant piece of Rotterdam's heritage.\n"}
#
# Result ID: 4822647, Score: 0.6963088512420654
# Metadata: {'title': 'Schiekade 77', 'main_category': 'house', 'subcategories': 'unique architecture, building', 'latitude': np.float64(51.92868333333333), 'longitude': np.float64(4.472561111111111), 'generated_text': 'This building at 77 Schiekade is a true gem of Rotterdam architecture. Built in 1896, it\'s a wonderful example of transitional architecture, a style bridging different architectural periods. Commissioned by builder C. Kurpershoek and designed by the Rotterdam architect P.G. Buskens, this former townhouse is a testament to craftsmanship.\n\nThe house is rectangular, featuring a basement, two floors, and an attic.  The facade, built with red brick and detailed with natural stone and yellow brick, is asymmetrically designed.  Notice the beautiful stained-glass windows and doors, some rectangular, some arched.  The steeply pitched roof is covered in slate. The gable ends are detailed with red brick and natural stone.\n\nTake a closer look at the ground floor.  You\'ll see a wooden service entrance, a triple window with round toplights, a semi-circular window, and the impressive stone staircase leading to the main entrance. On the main floor, admire the portico with its yellow brick round arch supported by a natural stone column.  The front door itself is a work of art, with decorative wood and wrought iron detailing.  Above the entrance, a balcony, framed by natural stone, adds a touch of elegance.\n\nLook closely at the decorative details.  The tile tableau above the entrance proclaims "sine labore nihil" – "nothing without labor.”  There\'s another tableau above a window, displaying the year 1896. A stone medallion with a knight\'s portrait is another notable detail.  The crowned cornice displays glazed tiles and sculpted figures: a lion and a young boy.  A small turret, featuring a three-light window and a tent roof with an iron crest, adds a distinct vertical element.\n\nEven the rear facade offers interesting features, such as projecting sections, balconies, and a loggia.  The interior retains original features including the patterned tile floors in the basement and the richly decorated hall and staircase.  Marble paneling, stucco work, and decorative doors contribute to the house\'s grandeur.  The hall features a mirror vault supported by decorated consoles.\n\n\nThis building is not just a beautiful structure; it\'s a significant piece of Rotterdam\'s history. Its architectural and cultural-historical value makes it a particularly important example of Schiekade architecture from before the Schie canal was filled in during World War II.  It\'s also notable as an early work in the career of architect P.G. Buskens.\n'}
#
# Result ID: 5490559, Score: 0.6939414739608765
# Metadata: {'title': 'Pannekoekstraat 46-48', 'main_category': 'building', 'subcategories': 'unique architecture, history', 'latitude': np.float64(51.92348888888888), 'longitude': np.float64(4.4879694444444445), 'generated_text': "This building at 46-48 Pannekoekstraat is more than just offices and apartments; it's a piece of Rotterdam's history.  Constructed between 1951 and 1953, it stands as a testament to the city's remarkable rebuilding after the devastating bombing of 1940.\n\nThe initial plans for Rotterdam's reconstruction, drafted just days after the bombing, envisioned a return to traditional architecture.  This building reflects that early vision.  Brick facades, windows with characteristic mullions, decorative elements, and the sloping roofs were all part of the plan to recreate the old city center, brick by brick.  While the overall approach to rebuilding later shifted towards more modern, functional designs, this building, along with a few others, remained true to this initial traditional style.  This was even though the architect who initially envisioned it was replaced in 1944.\n\nInterestingly, this project was spearheaded by Koos de Jong, a renowned builder and Olympic medalist, who commissioned the Rotterdam architectural firm Meischke and Schmidt. The building, with its shops on the ground floor,  business spaces at the rear, and six apartments across four floors, showcases a blend of practicality and traditional aesthetics. The use of gabled roofs, a hallmark of pre-war architecture, is a notable feature.  However, unlike typical pre-war buildings, this one incorporates a central stairwell, connecting the apartments into a single unit.\n\nAlthough admired for its unique design, the traditional style of this building wasn't universally embraced at the time.  A contemporary architectural journal expressed relief that the rest of the street wouldn't follow suit.  Today, however, it's recognised for its historical significance, and its status as a municipal monument reflects that appreciation. Its traditional design stands in contrast to the surrounding functionalist structures, making it a truly unique sight in this vibrant part of Rotterdam.\n"}
#
# Result ID: 782613, Score: 0.6925426125526428
# Metadata: {'title': 'Oostzeedijk', 'main_category': 'street', 'subcategories': 'neighbourhood, history', 'latitude': np.float64(51.921388888888885), 'longitude': np.float64(4.506388888888889), 'generated_text': "Welcome to the Oostzeedijk, a fascinating street in Rotterdam's Kralingen district.  This isn't just any street; it's a piece of Rotterdam's history, stretching approximately 1.2 kilometers.  Imagine its beginnings, part of the Schielands Hoge Zeedijk, a monumental dike built in the 12th century to protect the area from devastating floods. This impressive feat of engineering safeguarded the land between Gouda, Leiden, and Rotterdam for centuries.\n\nThe Oostzeedijk's architecture reflects its long history.  Many buildings date back to the period between 1890 and 1930. Of course, the bombing of Rotterdam in 1940 significantly altered the landscape, leaving its mark on the area.  Subsequent rebuilding efforts have shaped the street's current appearance, with some areas reflecting the post-war reconstruction and later developments like the striking De Admiraliteit skyscraper, a modern testament to the city’s maritime past.   \n\nAnother interesting building is the Industriegebouw, a significant industrial complex built in 1946. This building showcases the architectural style of its time.  Interestingly, the street also holds a significant industrial heritage: the site of the former Nieuwe Rotterdamsche Gasfabriek, built in 1852, once stood here.  This gasworks supplied the city with gas, and later an electricity plant operated on this site. Its presence contributes to a rich industrial past in the area.\n\nEven the street's functionality is worthy of note.  While the bulk of vehicular traffic is directed towards the Maasboulevard, the Oostzeedijk retains a calmer atmosphere. Its layout has been designed to accommodate trams and buses, with tram lines 1 and 11 running along it, connecting various parts of the city.  The relatively quiet setting and blend of old and new buildings give the street a distinctive character.  So, as you explore the Oostzeedijk, take a moment to appreciate its rich history and layered identity – a perfect blend of past and present.\n"}
#
# Result ID: 5407494, Score: 0.6920735836029053
# Metadata: {'title': 'Rotterdamsche Bank (Rotterdam)', 'main_category': 'monument', 'subcategories': 'unique architecture, building', 'latitude': np.float64(51.91923611111111), 'longitude': np.float64(4.479380555555555), 'generated_text': "This building, now a national monument, has a fascinating history. Originally, the Rotterdamsche Bank was housed in an 18th-century mansion on the Boompjes.  In 1912, it underwent a significant renovation, uncovering hidden murals during the process, and blending original features with a modern central hall. This impressive building, however, was tragically destroyed during the bombing of Rotterdam in 1940, leaving only the bank's vault intact.\n\nThe bank needed a new headquarters, and the Coolsingel was chosen as the location.  Construction began in 1941, but was interrupted by the war. Despite the setbacks, the new building was eventually completed in 1949, a testament to the city's resilience and reconstruction efforts.  The building itself is a unique blend of traditional and modern architectural styles. Its red brick facade features vertical windows, echoing earlier designs.  The rounded corners showcase classical columns and intricate sculptures.  The copper roof adds a striking, green hue.  Symbolic sculptures represent Rotterdam's key industries – agriculture, trade, fishing and shipping – both pre- and post-war.  The building’s interior was once equally impressive, featuring a grand hall, a double-height space for employees and a separate director's suite.\n\nThe building wasn't without its critics however.  Some felt that its imposing size and somewhat somber design clashed with the optimistic spirit of postwar reconstruction.  It was described as being too massive and dark, contrasting sharply with the vibrant atmosphere that was desired for the Coolsingel.   Regardless of these early criticisms, it remains a striking example of Rotterdam's architectural heritage, bearing witness to the city's journey through war and reconstruction, and having served as a major banking institution for many years. Today, it houses a bookstore and bank offices.\n"}

# %%
import folium
from IPython.display import display

def display_map_inline(results):
    """
    Display a map with markers for the retrieved locations.

    Args:
        results: List of query results from FAISS, each containing:
                 - id
                 - score
                 - metadata with fields: title, main_category, subcategories, latitude, longitude.
    Returns:
        A Folium map object.
    """
    # Ensure results exist
    if not results:
        print("No results to display.")
        return None

    # Initialize a map centered around the first result's coordinates
    first_location = results[0]['metadata']
    map_center = [first_location['latitude'], first_location['longitude']]
    map_object = folium.Map(location=map_center, zoom_start=12)

    # Add markers for each result
    for result in results:
        metadata = result['metadata']
        title = metadata.get('title', 'Unknown')
        latitude = metadata['latitude']
        longitude = metadata['longitude']
        main_category = metadata.get('main_category', 'N/A')
        subcategories = metadata.get('subcategories', 'N/A')

        # Add a marker with a popup
        popup_content = (
            f"<b>{title}</b><br>"
            f"Main Category: {main_category}<br>"
            f"Subcategories: {subcategories}"
        )
        folium.Marker(
            location=[latitude, longitude],
            popup=popup_content,
            tooltip=title,
        ).add_to(map_object)

    # Display the map directly in the notebook
    display(map_object)
    return map_object

# %%
# Example: Generate and display map
map_object = display_map_inline(results)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85e8845a24f23984b04273cedf5169cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85e8845a24f23984b04273cedf5169cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85e8845a24f23984b04273cedf5169cf = L.map(
#                 &quot;map_85e8845a24f23984b04273cedf5169cf&quot;,
#                 {
#                     center: [51.916575, 4.486402777777778],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfc38ef89d9f1b248b2689cdf8b9e5ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfc38ef89d9f1b248b2689cdf8b9e5ba.addTo(map_85e8845a24f23984b04273cedf5169cf);
#
#
#             var marker_7950e8a7a80a7ff1e2a8dc092cdbcdd1 = L.marker(
#                 [51.916575, 4.486402777777778],
#                 {
# }
#             ).addTo(map_85e8845a24f23984b04273cedf5169cf);
#
#
#         var popup_3143c48a67b7b8f6507698af9edf9851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdcc0042b8d4a1e95da9b1e769650c51 = $(`&lt;div id=&quot;html_bdcc0042b8d4a1e95da9b1e769650c51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Up:Town&lt;/b&gt;&lt;br&gt;Main Category: skyscraper&lt;br&gt;Subcategories: unique architecture, city&lt;/div&gt;`)[0];
#                 popup_3143c48a67b7b8f6507698af9edf9851.setContent(html_bdcc0042b8d4a1e95da9b1e769650c51);
#
#
#
#         marker_7950e8a7a80a7ff1e2a8dc092cdbcdd1.bindPopup(popup_3143c48a67b7b8f6507698af9edf9851)
#         ;
#
#
#
#
#             marker_7950e8a7a80a7ff1e2a8dc092cdbcdd1.bindTooltip(
#                 `&lt;div&gt;
#                      Up:Town
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3dbc8ca65fffcb495cb60db7ca1db239 = L.marker(
#                 [51.91793055555555, 4.477872222222223],
#                 {
# }
#             ).addTo(map_85e8845a24f23984b04273cedf5169cf);
#
#
#         var popup_c46f5111d00c50bc9e5199c5c41678c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35ebd03dfa1cbbfed463f46e1afe0bcc = $(`&lt;div id=&quot;html_35ebd03dfa1cbbfed463f46e1afe0bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rotterdam Centrum&lt;/b&gt;&lt;br&gt;Main Category: city&lt;br&gt;Subcategories: region, unique architecture&lt;/div&gt;`)[0];
#                 popup_c46f5111d00c50bc9e5199c5c41678c4.setContent(html_35ebd03dfa1cbbfed463f46e1afe0bcc);
#
#
#
#         marker_3dbc8ca65fffcb495cb60db7ca1db239.bindPopup(popup_c46f5111d00c50bc9e5199c5c41678c4)
#         ;
#
#
#
#
#             marker_3dbc8ca65fffcb495cb60db7ca1db239.bindTooltip(
#                 `&lt;div&gt;
#                      Rotterdam Centrum
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_17261d706866eaad075acbff652a236e = L.marker(
#                 [51.91861111111111, 4.488888888888889],
#                 {
# }
#             ).addTo(map_85e8845a24f23984b04273cedf5169cf);
#
#
#         var popup_674a48cbe0db3b3289291030cfcb0f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7bd78e01adc8be4abcd3fbc3a621646 = $(`&lt;div id=&quot;html_e7bd78e01adc8be4abcd3fbc3a621646&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Blaak 10&lt;/b&gt;&lt;br&gt;Main Category: building&lt;br&gt;Subcategories: unique architecture, monument&lt;/div&gt;`)[0];
#                 popup_674a48cbe0db3b3289291030cfcb0f79.setContent(html_e7bd78e01adc8be4abcd3fbc3a621646);
#
#
#
#         marker_17261d706866eaad075acbff652a236e.bindPopup(popup_674a48cbe0db3b3289291030cfcb0f79)
#         ;
#
#
#
#
#             marker_17261d706866eaad075acbff652a236e.bindTooltip(
#                 `&lt;div&gt;
#                      Blaak 10
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5c598bc07d82c133c57476c648597281 = L.marker(
#                 [51.907688888888885, 4.476897222222222],
#                 {
# }
#             ).addTo(map_85e8845a24f23984b04273cedf5169cf);
#
#
#         var popup_cf16fdd4b5194ac545ff6b28ea05c3da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49aa6209a391cb18eb9889c161846ce6 = $(`&lt;div id=&quot;html_49aa6209a391cb18eb9889c161846ce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Elevatorhuis&lt;/b&gt;&lt;br&gt;Main Category: building&lt;br&gt;Subcategories: unique architecture, art&lt;/div&gt;`)[0];

# %% [markdown]
# ## all-mpnet-base-v2

# %%
import json
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer

# %%
# Load embeddings from JSON file
embeddings_file = "embeddings/all-mpnet-base-v2_embeddings.json"
with open(embeddings_file, "r") as f:
    embeddings_data = json.load(f)

# Extract embeddings and IDs
embeddings = np.array([item["embedding"] for item in embeddings_data], dtype="float32")
ids = [item["id"] for item in embeddings_data]

# Load the metadata DataFrame
metadata_file = "nl_full_all_columns.csv"
metadata_df = pd.read_csv(metadata_file)

filtered_metadata_df = metadata_df[metadata_df["id"].isin(ids)].set_index("id")

# Normalize embeddings for cosine similarity
def normalize(vectors):
    norms = np.linalg.norm(vectors, axis=1, keepdims=True)
    return vectors / norms

embeddings_normalized = normalize(embeddings)

# Create a FAISS index for cosine similarity
dimension = embeddings_normalized.shape[1]  # Size of embedding vectors
index = faiss.IndexFlatIP(dimension)  # Inner product for cosine similarity
index.add(embeddings_normalized)

# Save the index to disk (optional)
faiss.write_index(index, "embeddings/all-mpnet-base-v2_faiss_index.index")

# %%
model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")

# Example Query
query_text = "What should a Rembrandt lover see in Leiden"
top_k = 20
results = query_faiss(index, query_text, model, filtered_metadata_df, ids, top_k)

# Display Results
print(f"Query: {query_text}\n")
for result in results:
    print(f"Result ID: {result['id']}, Score: {result['score']}")
    print(f"Metadata: {result['metadata']}\n")
# Out:
# Query: What should a Rembrandt lover see in Leiden
#
# Result ID: 549276, Score: 0.7298647165298462
# Metadata: {'title': 'Museum De Lakenhal', 'main_category': 'museum', 'subcategories': 'art, history', 'latitude': np.float64(52.16305555555555), 'longitude': np.float64(4.4875), 'generated_text': 'Step into Museum De Lakenhal, Leiden\'s municipal art museum since 1874. Housed in a stunning 1640 building, formerly the city\'s cloth hall, the museum beautifully blends Leiden\'s rich history with its remarkable art collection.  The museum\'s collection is primarily focused on Leiden\'s history, showcasing pieces depicting pivotal moments such as the Siege of Leiden in 1573-1574 and its subsequent relief.  You\'ll find masterpieces by renowned artists, including Rembrandt van Rijn, whose early work, "The Brillenverkoper,"  is one of the museum’s treasures.  Also on display are significant works by Lucas van Leyden, Jan Steen, Gerrit Dou, and many other significant Leiden artists.  The museum also boasts a substantial collection by Theo van Doesburg, who lived in Leiden when he founded the influential De Stijl movement in 1917, showcasing both older and modern art.\n\nThe museum\'s journey hasn’t been without its challenges and triumphs.  Its initial expansion in the late 19th century, funded by a generous donation, resulted in the addition of the impressive Harteveltzaal.  Further expansion followed in 1923 with the Papevleugel.  In 2006,  the museum played a prominent role in Rembrandt year, hosting several exhibitions dedicated to the master.   \n\nThen came a significant chapter: a comprehensive restoration and expansion project between 2016 and 2019.  This ambitious undertaking saw the museum completely renovated and expanded, revealing the original 1640 façade and incorporating a new wing. The museum reopened in 2019, following a meticulous restoration effort that carefully preserved the building\'s historical elements while also adding modern facilities and improved exhibition spaces.  The restoration not only highlighted the building\'s architectural beauty but also brought a renewed focus to the city\'s history, particularly the Leiden cloth industry. The museum now boasts significantly improved exhibition spaces, a larger capacity for temporary exhibitions, and expanded public facilities. The restoration process also unearthed hidden gems like long-lost windows in the former "Schuilkerk" (hidden church), which were restored and adorned with a stunning new stained-glass triptych.  \n\nWhile the reopening was met with positive reception, some critiques emerged regarding the balance of contemporary and historical art.  However, the museum actively addressed this by commissioning new works from ten contemporary artists, including four from Leiden itself, ensuring a vibrant representation of contemporary art alongside its historical collection.\n\nInterestingly, even while closed for renovations, the museum\'s spirit lived on.  In 2017, an open-air exhibition, “100 Years After De Stijl,” celebrated the centenary of the De Stijl movement.  This striking outdoor installation on the Pieterskerkhof  transformed the space with vibrant murals and installations, bringing the art of De Stijl to the heart of the city.  This temporary exhibition attracted a huge number of visitors.  The museum truly is a dynamic institution, seamlessly weaving together history, art and the vibrant life of Leiden.\n'}
#
# Result ID: 1685642, Score: 0.7118331789970398
# Metadata: {'title': 'Rembrandtbrug', 'main_category': 'bridge', 'subcategories': 'story, art', 'latitude': np.float64(52.161052777777776), 'longitude': np.float64(4.482216666666667), 'generated_text': "This bridge, a charming wooden structure, is a fascinating blend of old and new.  It's actually a modern reconstruction, built in 1983, meticulously replicating a 17th-century bridge that once stood in its place. The original was sadly demolished in 1817, leaving a gap in the cityscape for over a century and a half before this beautiful replica was erected.\n\nIts location is particularly significant. It’s named after the renowned painter Rembrandt van Rijn, who was born and spent his early years just a short distance away, in a lane called the Weddesteeg.  If you look to the south, you can almost imagine the young Rembrandt playing in the streets near this very spot.\n\nAnd if you turn your gaze north, you'll see another historically inspired landmark:  De Put, a windmill that's also a replica of one that existed during Rembrandt's lifetime. It’s interesting to note that Rembrandt's family owned a similar mill nearby.  So, as you stand here, you are standing at a place steeped in history and linked to one of the Netherlands' most celebrated artists. This quiet corner of Leiden offers a unique connection to the past, a tangible link to the world of Rembrandt.\n"}
#
# Result ID: 225055, Score: 0.6662489771842957
# Metadata: {'title': 'Rembrandthuis', 'main_category': 'museum', 'subcategories': 'art, house', 'latitude': np.float64(52.36944444444445), 'longitude': np.float64(4.9013888888888895), 'generated_text': "Welcome to the Rembrandt House Museum, situated in the heart of Amsterdam.  This building, dating back to around 1606, served as the home and studio of the renowned painter Rembrandt van Rijn between 1639 and 1658.  He purchased the house for a considerable sum – thirteen thousand guilders – and it underwent renovations, including the addition of a floor and a striking new façade, likely overseen by the architect Jacob van Campen.\n\nThe museum's collection offers a fascinating glimpse into Rembrandt's daily life. Based on an inventory from his bankruptcy in 1656, the house has been restored to reflect the atmosphere of a 17th-century home and artist’s studio. You’ll see his living room, art room and workshop – where he created his masterpieces.  In addition to the historical reconstruction, the museum displays a collection of 17th-century art, including works by Rembrandt's teacher Pieter Lastman and his students Ferdinand Bol and Govert Flinck.\n\nA remarkable feature of the museum is its nearly complete collection of Rembrandt's etchings, regularly showcased in a dedicated cabinet and temporary exhibitions.  Recent discoveries have further enriched our understanding of Rembrandt’s techniques.  In 1997, two pots were found in the house's cesspool. Analysis in 2019 confirmed that these pots contained the remains of quartz ground – a mixture of quartz and clay that Rembrandt used to prepare his canvases. This was a unique approach, possibly chosen for practical and economic reasons. You can see these very pots here in the museum.  The museum also continues to grow its collection, recently adding a painting by Ferdinand Bol, one of Rembrandt’s most famous pupils, as a donation from the Hoogsteder couple in 2021.  A further testament to the living nature of the museum is its acquisition of contemporary works by artists such as Natasja Kensmil and Milan Gies.\n\nThe museum also hosts temporary exhibitions in a modern wing, showcasing the works of Rembrandt, his contemporaries, and contemporary artists who have found inspiration in his work.  These exhibitions offer a diverse range of artistic styles and interpretations, continuing the legacy of this great master.  Even KLM, the Dutch airline, found inspiration in the building, using it as a model for one of their Delftware houses in 1976.  Your visit here is a journey through the life and work of Rembrandt, his era, and the continuing influence of his art.\n"}
#
# Result ID: 2308154, Score: 0.657258152961731
# Metadata: {'title': 'Latijnse school (Leiden)', 'main_category': 'building', 'subcategories': 'museum, unique architecture', 'latitude': np.float64(52.15839722222222), 'longitude': np.float64(4.487258333333333), 'generated_text': "Welcome to the former Latin School of Leiden, a truly remarkable building with a rich history.  Located on Lokhorststraat, this structure, dating back to 1599-1600, is a stunning example of the modern Renaissance style.  Imagine the skilled hands of the city mason, Jacob Dircxz. den Dubbelden, and the city stonemason, Claes Cornelisz. van Es, bringing this architectural masterpiece to life. Note the impressive stepped gable, broadened on the right, and the elegant Tuscan-style entrance.\n\nThis building holds a special place in art history.  Rembrandt van Rijn himself received his education within these very walls!  The Latin School served as a precursor to the Leiden Municipal Gymnasium, which departed in 1883. Following this, several other educational institutions found a home here. \n\nAfter years of serving as an educational hub, the building underwent a significant restoration in 1982, thanks to the efforts of the Diogenes Leiden Foundation.  Since then, it has been carefully preserved and serves as office space, ensuring that this important piece of Leiden's past continues to thrive in the present.  Take a moment to appreciate the architectural details, and envision the countless students who walked these halls centuries ago.\n"}
#
# Result ID: 5292987, Score: 0.6425556540489197
# Metadata: {'title': 'Jonge Rembrandt', 'main_category': 'statue', 'subcategories': 'art, square', 'latitude': np.float64(52.36004166666667), 'longitude': np.float64(4.905511111111111), 'generated_text': "Did you know that a sculpture called *Young Rembrandt*, created by Wim van Hoorn, exists in multiple places around the world?  The original, made in 1968 to commemorate the 300th anniversary of Rembrandt's death, was never fully completed.  Interestingly, the mold – and possibly the sculpture itself – ended up at Schiphol Airport. In the 2000s, Schiphol gifted copies to JFK International Airport near New York and Brisbane Airport.\n\nThere were once ambitious plans for a Rembrandt walking path, stretching eleven kilometers between Amsterdam and Ouderkerk aan de Amstel.  The route was envisioned to start at the Rembrandt House and follow the Amstel River, tracing locations where Rembrandt is believed to have painted.  Books like *Het landschap van Rembrandt* and *Op pad met Rembrandt* served as inspiration for this project.\n\nOne planned location for a marker along this path was Professor Tulpplein. This square is named after Nicolaes Tulp, famously immortalized by Rembrandt in his painting *The Anatomy Lesson of Dr. Nicolaes Tulp*.  And that's why, in 2011, a copy of *Young Rembrandt* found a home in the central reservation of the square.  A plaque notes that the sculpture was funded by several organizations including Delta Lloyd Vastgoed, Amstel Hotel, Stadsherstel Amsterdam, the municipality of Amsterdam, and the Stichting Rembrandt aan de Amstel.  It was unveiled on May 3rd, 2011.\n\nWhile another sculpture by Han Wezelaar was also planned to be part of the route, the Rembrandt path itself was never realised.  It's a fascinating story of artistic legacy and unrealized ambitions.\n"}
#
# Result ID: 266742, Score: 0.6212537288665771
# Metadata: {'title': 'Riekermolen', 'main_category': 'monument', 'subcategories': 'museum, story', 'latitude': np.float64(52.323888888888895), 'longitude': np.float64(4.893611111111111), 'generated_text': "Welcome to the Riekermolen, a historic windmill situated along the Amstel River.  This charming windmill boasts a fascinating history, having originally stood in the Riekerpolder south of the village of Sloten.\n\nDating back to 1636, this impressive structure played a vital role in the area's water management for centuries. However, in 1956, it faced demolition due to the expansion of the Nieuwe Meer lake.  Luckily, this beautiful piece of history was saved!  In 1961, the windmill was carefully relocated to its current location on the Kalfjeslaan.\n\nA unique aspect of this site is the presence of a Rembrandt statue, created by the artist Han Wezelaar. This sculpture commemorates the many drawings Rembrandt made along the banks of the Amstel River, a testament to the area's artistic legacy. The statue was unveiled in 1969, marking the 300th anniversary of Rembrandt's death.  It serves as a poignant reminder of the rich history interwoven into the landscape.\n\nThe Riekermolen is a significant reminder of Amsterdam’s past. Its survival and relocation stand as a tribute to the efforts in preserving Amsterdam's cultural heritage.  The windmill continues to stand as a testament to a time long past, serving as a peaceful and scenic landmark along the Amstel River.  Enjoy your visit!\n"}
#
# Result ID: 4535334, Score: 0.6164868474006653
# Metadata: {'title': 'Rijndijkbuurt', 'main_category': 'neighbourhood', 'subcategories': 'canal, street', 'latitude': np.float64(52.154025), 'longitude': np.float64(4.508261111111112), 'generated_text': "The Rijndijkbuurt neighborhood is a residential area located within the larger Roodenburgerdistrict of Leiden.  It's a fascinating area with a rich history, though much of its charm lies in its everyday life.  Think charming streets, quiet canals, and the everyday rhythm of a well-established community.  While it might not boast grand monuments or spectacular architecture in the way some other parts of Leiden do, the Rijndijkbuurt offers a glimpse into the authentic heart of the city – the lived experience of its residents.  It's a place where you can truly feel the pulse of Leiden, away from the bustling tourist trails.  Take your time to explore its quiet residential streets; you might discover hidden courtyards or stumble upon a local cafe offering a taste of authentic Dutch life.  The area’s history is subtly woven into its fabric, found in the age of some of the buildings and the quiet stories they hold.\n"}
#
# Result ID: 445491, Score: 0.5988955497741699
# Metadata: {'title': 'Huis Van Gijn', 'main_category': 'museum', 'subcategories': 'art, building', 'latitude': np.float64(51.81659166666666), 'longitude': np.float64(4.664113888888889), 'generated_text': 'Step into the Huis Van Gijn, a museum nestled in two monumental buildings in Dordrecht.  Imagine stepping back in time – that\'s exactly what this place offers.  The main building was once the home of Simon van Gijn, a banker with an extraordinary passion for collecting. He amassed a diverse collection – silver, ceramics, prints, furniture, even toys – all meticulously displayed within his home, essentially creating a museum within his own residence, centuries before the term was even fashionable.  \n\nThe museum was extensively renovated between 1999 and 2001. The entrance is through an adjacent building. Prepare to be amazed by the porcelain plates and dishes, not only from China and Japan, but also Dutch earthenware depicting the Orange-Nassau family.  Marvel at antique clocks, paintings, Flemish tapestries, and an impressive collection of silverware.  \n\nLet\'s explore some key rooms.  The "Zaal," or hall, is furnished in the style of Louis XIV, predating Van Gijn by over a century.  The interior, remarkably unchanged, was preserved through the wishes of previous owners and Van Gijn himself, who enshrined its protection in his will. \n\nNext, we have the Vriesendorp Salon, the domain of Cornelia Agatha Vriesendorp, where Mrs. Van Gijn received her high-society guests.  A remarkable feature here is the reconstructed Spanish rose marble mantelpiece.\n\nThe Dining Room reflects Van Gijn\'s prominent status in Dordrecht. He regularly hosted lavish dinners here. In 1886, he remodeled this room in 17th-century style, complete with wall and ceiling paintings in the Dutch Renaissance style. \n\nThe Garden Room served as a place for tea, piano playing, and evening games.  It houses a lacquered mahogany display case from 1886, the only original piece of furniture remaining from that time.  You\'ll also find a table piano made around 1840 by the Broedelet company in Utrecht – a later addition, but showcased in the same spot where the Van Gijns’ own piano once stood, complete with two stools for four-hand playing.\n\nA significant addition to the Garden Room is the conservatory, built onto the back in 1886. From here, you can admire the rose garden he later created. A meticulous reconstruction of a garden house, originally demolished in the 1930s, is also a focal point here, using a 1904 photograph as a precise guide.\n\nThe kitchen, largely unchanged since the house\'s construction in 1729, though the stove and utensils are later additions. Adjoining it is a small pantry for preserved goods and, via a small staircase, a cellar for storing wine.\n\nAscending to the upper floors, you\'ll find Van Gijn\'s use of the first floor hallway as an early display space for his collection.  Alongside two bedrooms, a library and study with a view of the Nieuwe Haven showcase 1886 Dutch Renaissance style.  Also on this floor lies the "gold leather room" with a complete 17th-century interior from another Dordrecht house.\n\nThe second floor, originally for staff, is furnished to reflect that time – laundry and drying areas, storage rooms, bedrooms, and a print room. Finally, the attic – a treasure trove of toys!  Many of Simon van Gijn’s childhood toys survived, forming the basis of a large collection that includes dollhouses and vintage tin toys, even a small fairground with a glittering carousel.  This remarkable collection is a testament to a bygone era, a fitting end to this journey through time.\n'}
#
# Result ID: 3829578, Score: 0.5889672040939331
# Metadata: {'title': 'Binnenstad zuid', 'main_category': 'neighbourhood', 'subcategories': 'city, unique architecture', 'latitude': np.float64(52.15832777777778), 'longitude': np.float64(4.488652777777778), 'generated_text': "Welcome to Leiden's South Inner City, a vibrant heart of this historic Dutch city. This district, encompassing Pieterswijk, Academiewijk, and the western and eastern parts of Levendaal, is packed with history.  It's a place where centuries of stories are woven into the very fabric of the streets.\n\nYou'll find yourself surrounded by an incredibly high concentration of nationally protected monuments.  These buildings, many dating back hundreds of years, whisper tales of Leiden’s rich past. From grand residences to charming smaller buildings, each structure adds to the unique character of this area. This is why it is so popular with visitors from all over.  \n\nAs you explore, take your time to appreciate the architectural details, the intricate carvings, and the stories hidden within the walls. Let the atmosphere transport you back in time, allowing you to feel the pulse of a city that has witnessed centuries of change.  It's a place where history comes alive, inviting you to explore and discover its many hidden gems.  Enjoy your exploration of this remarkable area.\n"}
#
# Result ID: 4398725, Score: 0.5853967666625977
# Metadata: {'title': 'Rembrandtmonument', 'main_category': 'statue', 'subcategories': 'monument, art', 'latitude': np.float64(52.366), 'longitude': np.float64(4.896591666666666), 'generated_text': 'This monument, erected in 1852, is a tribute to Rembrandt van Rijn, one of the Netherlands\' most celebrated painters. The idea for a statue first emerged in 1838, sparked by a writer advocating for a lasting memorial to the artist.  An initial design, depicting Rembrandt seated and sketching, was proposed but ultimately superseded.  \n\nFollowing a friendly gathering of Belgian and Dutch artists in 1841, the project gained momentum. A committee was formed, and a nationwide fundraising campaign was launched.  The chosen sculptor, Louis Royer, a renowned artist who held the title "Sculptor to the King," was commissioned despite some controversy. He created a new design, showcasing Rembrandt standing in 17th-century attire.\n\nThe creation of the statue was not without its challenges.  Political unrest, financial difficulties, and accidents during the casting process caused delays. Eventually, in 1852, the cast iron statue was unveiled, a grand event attended by King Willem III and numerous dignitaries.  The unveiling was followed by a lavish celebration including a ball and a lottery of artworks.\n\nThe statue has been moved and rotated several times throughout the years, adapting to changes in the square. The current placement, resulting from a 2009 renovation, ensures a prominent position. The statue stands as a testament to Rembrandt\'s legacy and as an important example of 19th-century Dutch sculpture, its presence marked by intricate detail and powerful symbolism.  The statue itself shows Rembrandt in his characteristic clothing, holding an etching needle, with various artist’s tools at his feet.  A small bronze replica of Rembrandt\'s masterpiece, "The Night Watch," was displayed near the monument until 2020.   The statue is recognized as a national monument of great historical and artistic value.\n'}
#
# Result ID: 5407224, Score: 0.583086371421814
# Metadata: {'title': 'Rembrandthuisje', 'main_category': 'building', 'subcategories': 'art, street art', 'latitude': np.float64(52.36602777777778), 'longitude': np.float64(4.896), 'generated_text': "This small building on Rembrandt Square may not look like much at first glance.  It's actually a transformer station, a rather unassuming structure from the early 2000s. But look closer! In 2011, local entrepreneur and self-proclaimed artist Peter Doeswijk, in collaboration with the Rembrandtplein business association, Liander (the energy company), and even the Rembrandt House Museum, decided to brighten things up considerably.  The exterior walls were transformed with reproductions of Rembrandt van Rijn's drawings and etchings.  It's a delightful surprise, a vibrant splash of art in an unexpected place.  Doeswijk, incidentally, has a reputation for adding unexpected artistic touches to the Amsterdam cityscape. He's been known to create photo collages for road closures and even designs for temporary walkways over cable trenches.  So next time you're near Rembrandt Square, take a moment to appreciate this little gem – a testament to the power of art to enliven even the most utilitarian of structures.\n"}
#
# Result ID: 2894717, Score: 0.5810539722442627
# Metadata: {'title': 'Museum W', 'main_category': 'museum', 'subcategories': 'art, history', 'latitude': np.float64(51.25356111111111), 'longitude': np.float64(5.7062083333333335), 'generated_text': "Welcome to Museum W, housed in the former Weert town hall, a building with a rich history dating back to 1543.  While much of the original structure was altered over the centuries, you can still see a significant portion of the original south facade and the cellars.  The building’s current appearance, designed by J. Rouleau,  dates from 1913.  Recently renovated and reopened in 2022, the museum boasts a stunning new gold-colored facade, a design by Limburgian artist Maurice Mentjens.\n\nThe museum's collection is a fascinating blend of regional and religious artifacts.  A major focus is the spiritual heritage of St. Francis of Assisi and the history of the Franciscan order in the Netherlands.  This includes paintings, sculptures, silverware, textiles, and objects of popular devotion spanning several centuries.  The collection boasts a remarkable number of works from the Dutch Franciscan order, including nineteen paintings by the 18th-century artist Jacob de Wit. These are from the former Franciscan rectory of the Moses and Aaron Church in Amsterdam.  Other notable painters represented include 17th-century masters such as Pieter de Grebber and Jan Lievens. The museum also houses a significant collection of portraits of priests and chaplains.\n\nAmong the most treasured items is West Europe’s oldest known nativity scene, dating from the early 16th century.  Also on display are devotional objects, textiles like chasubles and lacework from the 15th century onward, and a substantial collection of religious goldsmith’s work from the 17th to the 20th century, including a significant number of pieces from the Esser workshops of Weert. Since 2011, the museum has also housed the workshop’s complete studio collection comprising thousands of drawings, models, and tools.\n\nBeyond religious art, Museum W showcases the region’s artistic heritage. You'll find medieval sculptures and paintings, including a 13th-century seated Madonna and Child, and works by notable artists like Jan van Steffeswert and Barend van Orley. The museum's collection also includes 19th and 20th-century works by artists such as Charles Vos, Désirée Tonnaer and David Groen.\n\nThe museum’s holdings also extend to artifacts from the region’s rich prehistory and history, with items from the Stone Age, Bronze Age, Iron Age, and Roman periods. These include tools, pottery, jewellery and even bronze wine strainers and basins.  The late Middle Ages are represented by items such as tin city jugs, and the museum also explores the history of the lords of Weert and the local guilds.  Items from the early industrial period include pipes from the Trumm-Bergmans factory and several longcase clocks made by Weert clockmakers of the 18th century, like Petronella van den Wijngaard, Nicolaas Gregoire, and Petrus A. de Coster. Finally, the museum also includes a collection of regional modern and contemporary art.  Enjoy your visit!\n"}
#
# Result ID: 315790, Score: 0.5776191353797913
# Metadata: {'title': 'De Bijenkorf (Rotterdam)', 'main_category': 'building', 'subcategories': 'museum, shopping', 'latitude': np.float64(51.92027777777778), 'longitude': np.float64(4.478888888888889), 'generated_text': 'Welcome to the iconic De Bijenkorf department store in Rotterdam. This impressive building, one of the three largest in the chain, stands as a powerful symbol of Rotterdam\'s post-war reconstruction.  Built in 1957, it\'s a flagship store – one of the most important locations in the entire Bijenkorf network. For a long time, Amsterdam, The Hague, and Rotterdam were the only Bijenkorf locations in the Netherlands.\n\nThe building itself boasts a prime location opposite the Stock Exchange on Coolsingel, and since 2012, it stands proudly next to the B\'Tower.  It was designed by the Hungarian-American architect Marcel Breuer, replacing a previous building that had been severely damaged during the bombings of World War II.\n\nDid you know that the building also houses a piece of history?  Originally a cinema called Cineac-NRC, and later known as Cineac Bijenkorf (from 1977),  this part of the complex –  accessible directly from the department store – is now a wok restaurant. The entire complex, including the former cinema, holds a protected national monument status.\n\nThe Bijenkorf is not just a shopping destination, it\'s also a showcase for art.  In front of the building stands "De Gestileerde Bloem," a sculpture by Naum Gabo. It was actually commissioned to meet a city requirement for a specific building line. Inside, you’ll find a replica of a lost stained-glass window by Theo van Doesburg and a sculpture by the renowned Henry Moore.\n\nSo, as you explore this architectural masterpiece and enjoy your shopping experience, remember that you’re not just visiting a department store; you\'re also experiencing a piece of Rotterdam\'s rich history and artistic heritage.\n'}
#
# Result ID: 2411691, Score: 0.5769672989845276
# Metadata: {'title': 'Logement van Leiden', 'main_category': 'house', 'subcategories': 'building, story', 'latitude': np.float64(52.07873333333334), 'longitude': np.float64(4.311269444444444), 'generated_text': "Step into a piece of Dutch history here at Buitenhof 22. This building, known as the Logement van Leiden, has witnessed centuries of political intrigue and social change.  Built in 1636, it served as a lodging house for representatives from the city of Leiden attending meetings of the States of Holland.  Imagine the bustling activity within these walls – diplomats, messengers, and perhaps even the occasional heated debate.\n\nFor over 160 years, this building served as a vital hub for Leiden's political presence in the Hague. It originally featured a grand gate and the city's coat of arms, proudly displayed for all to see. While these features are no longer visible, their legacy remains embedded in the building's very structure.\n\nIn 1799, the Logement van Leiden was sold to the Besognekamer, a council that had to relocate from the Binnenhof due to the arrival of the French.  This event marks a significant turning point, mirroring the broader changes sweeping through the Netherlands at the time.\n\nThe building’s long history offers a fascinating glimpse into the complex political landscape of 17th-century Holland, a period when many cities maintained similar lodgings in the Hague for their delegates.  The Logement van Leiden stands as a silent testament to this era, a reminder of the historical connections between Leiden and Den Haag. As you continue your exploration, consider the stories whispered within these walls, stories of power, diplomacy, and the enduring spirit of a city’s representation.\n"}
#
# Result ID: 5720778, Score: 0.576414167881012
# Metadata: {'title': 'Zonder titel (Jan van Goethem, Reinwardtstraat)', 'main_category': 'statue', 'subcategories': 'street art, unique architecture', 'latitude': np.float64(52.36119166666667), 'longitude': np.float64(4.927544444444445), 'generated_text': "We're standing in front of a fascinating piece of public art, tucked away on the northern wall of Reinwardtstraat. This artwork, created by Jan van Goethem around 1982, is actually one of a pair; its twin sits just around the corner on Pieter Nieuwlandstraat.\n\nThe building itself is a striking example of 1980s architecture, with its constantly shifting facade – a playful interplay of projections and recesses, nooks and balconies.  Van Goethem's artwork occupies a blank wall on a section of the building that juts forward. High on the facade, this glass and neon sculpture is a real eye-catcher.\n\nThe piece consists of a central vertical column from which two other columns ascend, reaching towards the sky. At the roofline, these columns bend at a 90-degree angle. Within the resulting space, Van Goethem placed a square divided into four segments by a cross. Interestingly, according to Buitenkunst Amsterdam, this design is a response to the many satellite dishes that once adorned this neighbourhood. The geometry, so characteristic of Van Goethem's style, is beautifully highlighted at night when the artwork is illuminated.\n\nA 1985 article in the Volkskrant newspaper described the artwork as a remarkable example of art integrated into social housing – a feature largely absent since the era of the Amsterdam School architectural style. This integration of art and architecture reflects Van Goethem's background, having studied at the Academy of Architecture in Tilburg. But while he embraced architectural design, his true passion was drawing. If you are interested in seeing more of Van Goethem's work, you can find other pieces at the Slotervaart Hospital and the Voorsteven building in other parts of Amsterdam.\n"}
#
# Result ID: 4463579, Score: 0.5742586255073547
# Metadata: {'title': "D'Oude Morsch", 'main_category': 'neighbourhood', 'subcategories': 'city, story', 'latitude': np.float64(52.16265277777778), 'longitude': np.float64(4.4836), 'generated_text': "D'Oude Morsch is a charming residential neighborhood nestled within Leiden's Binnenstad-Noord district.  It's a fascinating area with a rich history, although much of its past is subtly woven into the fabric of its streets and buildings. While not immediately striking, its quiet beauty is something to be discovered.  Take a moment to imagine the lives lived here through the centuries – the sounds of children playing, the clatter of daily life, and the stories that these homes could tell if only the walls could speak.  Pay attention to the details of the architecture; you may notice subtle variations in style reflecting different periods and the changing tastes of its inhabitants.  D'Oude Morsch offers a glimpse into the everyday history of Leiden, showcasing a more intimate and less publicized side of this vibrant city.  It’s a wonderful place to simply stroll and soak in the atmosphere, letting the quiet charm of the neighborhood work its magic.\n"}
#
# Result ID: 1552135, Score: 0.5692520141601562
# Metadata: {'title': 'Witte Singel', 'main_category': 'canal', 'subcategories': 'water, street', 'latitude': np.float64(52.15416666666667), 'longitude': np.float64(4.482777777777778), 'generated_text': "Welcome to the Witte Singel, a canal and street forming part of Leiden's 17th-century ring of canals encircling the city center.  We're tracing its course from the Galgewater, a branch of the Old Rhine river, to the Zoeterwoudsesingel.  Notice how the street runs along the outer edge of the canal. The inner side, facing the city center, is largely without streets, with the exception of the Boisotkade.\n\n\nLet's explore some notable landmarks along the Witte Singel. On the inner, city-facing side, you'll find the renowned Hortus Botanicus, a botanical garden of great historical significance.  Nearby is the Old Observatory, situated on what was once a defensive bastion.  The area also houses the LAKtheater, several faculties of Leiden University, the Leiden Regional Archives, and the Van der Klaauw Laboratory.\n\n\nNow, let's shift our attention to the outer side of the canal, where the street itself runs. Here, you can admire the striking building of the Leidsch Dagblad, newspaper headquarters, a masterpiece of Dudok architecture. Further along you'll find the University Library and the striking residential complex known as ‘De Draaimolen’, showcasing unique Jesse architecture.\n\n\nThe Witte Singel offers a fascinating blend of historical charm, academic prominence, and modern architectural design, all within a beautiful canal-side setting. I hope you enjoy exploring this vibrant part of Leiden.\n"}
#
# Result ID: 4496753, Score: 0.5678566694259644
# Metadata: {'title': 'Raadsherenbuurt', 'main_category': 'neighbourhood', 'subcategories': 'house, story', 'latitude': np.float64(52.17632777777778), 'longitude': np.float64(4.478641666666666), 'generated_text': 'Welcome to the Raadsherenbuurt neighborhood in Leiden.  This charming residential area is part of the larger Boerhaavedistrict.  It\'s a fascinating place with a rich history, though much of that history isn\'t immediately visible. The name itself, "Raadsherenbuurt," translates to "Councilors\' Neighborhood," hinting at its past residents.  Imagine the lives lived here centuries ago, the stories shared within these walls.  The architecture of the houses, while not uniformly styled, reflects different periods and styles, offering a glimpse into the evolving tastes and building practices of Leiden.\n\nTake your time to explore the streets and soak in the atmosphere. You’ll find a mix of homes, creating a blend of old and new.  The calm, residential atmosphere offers a peaceful respite from the busier parts of Leiden.  While perhaps not immediately obvious, the neighborhood’s history is evident in the details - in the subtle architectural variations between the buildings, and in the overall layout of the streets themselves.  As you walk, try to picture the past residents and their daily routines.  Imagine the conversations that echoed through these streets generations ago, connecting the past to the present.   This neighborhood represents a piece of Leiden\'s enduring character, a quiet testament to the city’s layered history and the evolving lives of its inhabitants.\n'}
#
# Result ID: 4540938, Score: 0.5669988393783569
# Metadata: {'title': 'Professorenwijk-Oost', 'main_category': 'neighbourhood', 'subcategories': 'unique architecture, house', 'latitude': np.float64(52.14946944444444), 'longitude': np.float64(4.506288888888889), 'generated_text': "Welcome to Professorenwijk-Oost, a charming residential area in the heart of Leiden. This neighborhood, along with its sister areas Professorenwijk-West and Burgemeesterswijk, forms a unique urban landscape.  Designed as a single entity by the architectural firm of Granpré Molière, Verhagen and Kok, these areas share a distinct and cohesive architectural style, making them instantly recognizable.  You'll notice a consistent aesthetic as you explore, reflecting the careful planning and design that went into their creation.  The streets are lined with beautiful homes, many of which retain their original character and charm, offering a glimpse into Leiden's rich history.  Take your time to wander through these streets, absorbing the ambiance and appreciating the architectural details. The careful planning offers a serene atmosphere making this an ideal place for a peaceful stroll.\n"}
#
# Result ID: 1099552, Score: 0.5668835639953613
# Metadata: {'title': 'Haags Historisch Museum', 'main_category': 'museum', 'subcategories': 'city, art', 'latitude': np.float64(52.08131666666667), 'longitude': np.float64(4.3141388888888885), 'generated_text': 'Welcome to the Hague Historical Museum, housed in the former Saint Sebastian\'s Range. Here, you\'ll journey through the captivating history of The Hague, a city steeped in rich heritage and political significance.\n\nThe museum boasts a remarkable collection of over 7,500 objects.  Imagine gazing upon a nearly five-meter-wide cityscape of The Hague painted by the master Jan van Goyen, or examining intricately detailed dollhouses created by the renowned Lita de Ranitz.  The collection also includes fascinating artifacts, such as silverware from various guilds, paintings by celebrated artists like Jan van Ravesteyn, Paulus Constantijn La Fargue, and Jan Steen. And, remarkably, you can see the preserved finger of Cornelis de Witt and the tongue of his brother, Johan de Witt – chilling reminders of a turbulent past.\n\nThe museum’s permanent exhibition, "Power – 800 Years of the Binnenhof," unfolds on the main floor, narrating The Hague\'s story, focusing especially on the Binnenhof.  Through a compelling display of objects and paintings spanning from the 16th to the 21st centuries, you\'ll witness the city\'s evolution.\n\nRotating exhibitions on the first floor delve into various aspects of Hague life, exploring themes such as the iconic band Golden Earring, the renowned artist Isaac Israëls, and even the unique humor of The Hague.  The second floor is dedicated to the city\'s history since 1945, featuring more of Lita de Ranitz\'s captivating dollhouses.\n\nIn the basement, you’ll find a rotating exhibition of artifacts from the “My Hague” project, offering personal narratives that connect individual stories with the city\'s broader history.  And, for a touch of the past, the museum also features a meticulously recreated 19th-century salon, where children, during weekends and school holidays, can engage in interactive experiences to understand how life was lived in The Hague during that era.  It\'s a wonderful opportunity to bring history to life for younger visitors.\n'}

# %%
t = display_map_inline(results)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a9c45aba5e1f12b5329cd438179607d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a9c45aba5e1f12b5329cd438179607d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a9c45aba5e1f12b5329cd438179607d = L.map(
#                 &quot;map_6a9c45aba5e1f12b5329cd438179607d&quot;,
#                 {
#                     center: [52.16305555555555, 4.4875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9d5057734dd2a35841a3df05eb4ca39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9d5057734dd2a35841a3df05eb4ca39.addTo(map_6a9c45aba5e1f12b5329cd438179607d);
#
#
#             var marker_c8cf6b20121968163dc4fae228a79b58 = L.marker(
#                 [52.16305555555555, 4.4875],
#                 {
# }
#             ).addTo(map_6a9c45aba5e1f12b5329cd438179607d);
#
#
#         var popup_2824913ba49627b849045c67441f1cee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e690d02ade2cc78a4087fcd2c74d2d1 = $(`&lt;div id=&quot;html_9e690d02ade2cc78a4087fcd2c74d2d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Museum De Lakenhal&lt;/b&gt;&lt;br&gt;Main Category: museum&lt;br&gt;Subcategories: art, history&lt;/div&gt;`)[0];
#                 popup_2824913ba49627b849045c67441f1cee.setContent(html_9e690d02ade2cc78a4087fcd2c74d2d1);
#
#
#
#         marker_c8cf6b20121968163dc4fae228a79b58.bindPopup(popup_2824913ba49627b849045c67441f1cee)
#         ;
#
#
#
#
#             marker_c8cf6b20121968163dc4fae228a79b58.bindTooltip(
#                 `&lt;div&gt;
#                      Museum De Lakenhal
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b72ecd1766837ac1a370517308682344 = L.marker(
#                 [52.161052777777776, 4.482216666666667],
#                 {
# }
#             ).addTo(map_6a9c45aba5e1f12b5329cd438179607d);
#
#
#         var popup_dd9d1171620f37831a2627bf1875b35f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65f09af337aa07b121b9f9c3f65c88d4 = $(`&lt;div id=&quot;html_65f09af337aa07b121b9f9c3f65c88d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rembrandtbrug&lt;/b&gt;&lt;br&gt;Main Category: bridge&lt;br&gt;Subcategories: story, art&lt;/div&gt;`)[0];
#                 popup_dd9d1171620f37831a2627bf1875b35f.setContent(html_65f09af337aa07b121b9f9c3f65c88d4);
#
#
#
#         marker_b72ecd1766837ac1a370517308682344.bindPopup(popup_dd9d1171620f37831a2627bf1875b35f)
#         ;
#
#
#
#
#             marker_b72ecd1766837ac1a370517308682344.bindTooltip(
#                 `&lt;div&gt;
#                      Rembrandtbrug
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a19773808d98b6663f946a18a96bb0b8 = L.marker(
#                 [52.36944444444445, 4.9013888888888895],
#                 {
# }
#             ).addTo(map_6a9c45aba5e1f12b5329cd438179607d);
#
#
#         var popup_c82912d42aa88b02a12844dddb40d5ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_673b0796ce1b0b7fbcce2cb2d2b5c2b7 = $(`&lt;div id=&quot;html_673b0796ce1b0b7fbcce2cb2d2b5c2b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Rembrandthuis&lt;/b&gt;&lt;br&gt;Main Category: museum&lt;br&gt;Subcategories: art, house&lt;/div&gt;`)[0];
#                 popup_c82912d42aa88b02a12844dddb40d5ed.setContent(html_673b0796ce1b0b7fbcce2cb2d2b5c2b7);
#
#
#
#         marker_a19773808d98b6663f946a18a96bb0b8.bindPopup(popup_c82912d42aa88b02a12844dddb40d5ed)
#         ;
#
#
#
#
#             marker_a19773808d98b6663f946a18a96bb0b8.bindTooltip(
#                 `&lt;div&gt;
#                      Rembrandthuis
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_65dc9896b890d8671b9c3074584efb59 = L.marker(
#                 [52.15839722222222, 4.487258333333333],
#                 {
# }
#             ).addTo(map_6a9c45aba5e1f12b5329cd438179607d);
#
#
#         var popup_64fdd0f8e1323608956b4833576cc0d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_681bc378fa0f634eb4cfdc686b32fb90 = $(`&lt;div id=&quot;html_681bc378fa0f634eb4cfdc686b32fb90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Latijnse school (Leiden)&lt;/b&gt;&lt;br&gt;Main Category: building&lt;br&gt;Subcategories: museum, unique architecture&lt;/div&gt;`)[0];
#                 popup_

# %% [markdown]
# ## NovaSearch/stella_en_1.5B_v5

# %%
import json
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer

# %%
# Load embeddings from JSON file
embeddings_file = "embeddings/stella_en_1_5B_v5_embeddings.json"
with open(embeddings_file, "r") as f:
    embeddings_data = json.load(f)

# Extract embeddings and IDs
embeddings = np.array([item["embedding"] for item in embeddings_data], dtype="float32")
ids = [item["id"] for item in embeddings_data]

# Load the metadata DataFrame
metadata_file = "nl_full_all_columns.csv"
metadata_df = pd.read_csv(metadata_file)

filtered_metadata_df = metadata_df[metadata_df["id"].isin(ids)].set_index("id")

# Normalize embeddings for cosine similarity
def normalize(vectors):
    norms = np.linalg.norm(vectors, axis=1, keepdims=True)
    return vectors / norms

embeddings_normalized = normalize(embeddings)

# Create a FAISS index for cosine similarity
dimension = embeddings_normalized.shape[1]  # Size of embedding vectors
index = faiss.IndexFlatIP(dimension)  # Inner product for cosine similarity
index.add(embeddings_normalized)

# Save the index to disk (optional)
faiss.write_index(index, "embeddings/stella_en_1_5B_v5_embeddings_faiss_index.index")

# %%
model = SentenceTransformer("NovaSearch/stella_en_1.5B_v5")

# Example Query
query_text = "brutalist architecture Amsterdam"
top_k = 20
results = query_faiss(index, query_text, model, filtered_metadata_df, ids, top_k)

# Display Results
print(f"Query: {query_text}\n")
for result in results:
    print(f"Result ID: {result['id']}, Score: {result['score']}")
    print(f"Metadata: {result['metadata']}\n")
# Out:
# Query: brutalist architecture Amsterdam
#
# Result ID: 1765510, Score: 0.6337276697158813
# Metadata: {'title': 'ARCAM', 'main_category': 'museum', 'subcategories': 'art, architecture', 'latitude': np.float64(52.37145), 'longitude': np.float64(4.912647222222223), 'generated_text': "ARCAM, the Amsterdam Centre for Architecture, is a fascinating institution dedicated to architecture, urban planning, and landscape architecture in and around Amsterdam.  Founded in 1985 by Maarten Kloos, it arose from a need to coordinate the fragmented knowledge within the architectural field in the city.  Initially located in the Academy of Architecture building, its growth necessitated a move to a pavilion near the NEMO Science Museum in the late 1990s, where it remains today.\n\nARCAM’s activities are diverse and engaging.  They’ve overseen projects ranging from creating comprehensive maps charting the architectural landscape, to organizing exhibitions and debates focusing on Amsterdam's future development – exploring areas like its coastal zones. The organization also has a significant role in the prestigious Amsterdam Architecture Prize, annually rewarding outstanding architectural achievements within the city, accompanied by publications highlighting the best buildings. ARCAM also hosts exhibitions and lectures, featuring the work of renowned architects like Herman Hertzberger, showcasing designs and engaging the public in ongoing dialogues surrounding the built environment of Amsterdam.  Over the years, it has also utilized spaces such as the former Amphitrite island in the Oosterdok harbor for projects. Through its various initiatives, ARCAM plays a crucial role in shaping the architectural discourse and appreciation of Amsterdam.\n"}
#
# Result ID: 2977710, Score: 0.619277834892273
# Metadata: {'title': 'Villa De Wachter', 'main_category': 'house', 'subcategories': 'unique architecture, art', 'latitude': np.float64(52.14163333333333), 'longitude': np.float64(5.363725), 'generated_text': "This elegant villa before you is a true gem of Amersfoort's architectural heritage, a testament to the artistry of the Amsterdam School.  Designed by the renowned architect Hendrik Wijdeveld, and built between 1927 and 1929, it stands as a superb example of the style, incorporating elements of zakelijk expressionisme, a movement characterized by its functional yet expressive forms. Notice the characteristic details – the interplay of brickwork and the thoughtful integration of materials. The building's design beautifully reflects the ideals of the era, showcasing a harmonious blend of functionality and artistic expression.  It's a captivating example of early 20th-century Dutch architecture, showcasing the dynamism and innovation of the time.  Take a moment to appreciate its timeless beauty and the skill of its creator.\n"}
#
# Result ID: 5795896, Score: 0.6183359622955322
# Metadata: {'title': 'Bijdorpplantsoen 8-10', 'main_category': 'building', 'subcategories': 'unique architecture,  housing', 'latitude': np.float64(52.336475), 'longitude': np.float64(4.926305555555556), 'generated_text': "This impressive building at Bijdorpplantsoen 9-10 in Amsterdam East is a striking example of modern architecture. Completed in the summer of 2023, it's a project of De Alliantie, a housing corporation.  The structure houses a unique combination of 280 student residences and 200 hotel rooms, exclusively for students who need temporary accommodation in the city.  This innovative approach provides much-needed student housing while also offering a place for students to stay for longer periods.\n\nThe building boasts a considerable size of approximately 20,000 square meters, stretching 100 meters in length and rising to twelve floors.  Its design, by Ludo Grooteman of Moke Architects, is characterized by a fascinating facade.  The exterior is divided into a series of setbacks and projections, creating a dynamic interplay of light and shadow.  One architectural critic described it as a segmented facade with holes, indentations, offsets, a gateway, and a terrace; truly a unique design.  The interior design was handled by Fiction Factory, further contributing to the building's unique character.\n\nInterestingly, the building incorporates sustainable practices.  A portion of the construction materials and even some interior furnishings, like textiles from a Rijksmuseum exhibition, were repurposed.  This commitment to sustainability contributed to the building’s recognition as one of the ten most promising buildings in Amsterdam in 2023 by ARCAM,  for the Amsterdam Architecture Prize.  Beneath the student housing and hotel, commercial spaces provide additional functionality, adding to the versatility and vibrancy of the building.  A bicycle storage area and a small car park for thirteen vehicles complete the complex.\n"}
#
# Result ID: 2150389, Score: 0.6123051047325134
# Metadata: {'title': 'Olympia (Amsterdam)', 'main_category': 'building', 'subcategories': 'unique architecture, house', 'latitude': np.float64(52.34711111111111), 'longitude': np.float64(4.860505555555555), 'generated_text': "This complex, called Olympia, is a striking example of Amsterdam School architecture.  Built between 1924 and 1926, it's comprised of five interconnected residential blocks, containing over 500 homes and commercial spaces.  The architect, Jan Gratama, designed it as part of a larger urban development plan for the Stadionbuurt neighborhood, which itself was based on the ambitious Plan Zuid – a significant expansion of Amsterdam to the south.\n\nGratama's work here is not isolated.  He collaborated with Jan-Willem Dinger on other buildings in the area, creating a cohesive architectural style along the Marathonweg.  While Gratama oversaw the broader development, other architects contributed to the diverse styles you see throughout the Marathonbuurt.\n\nThe initial construction of Olympia was undertaken by the N.V. Bouw- en Exploitatiemaatschappij Haga, with the intention of providing affordable housing.  An unexpected change occurred when the intended housing association declined to manage the completed complex, leaving the city to take on the responsibility. This led to the municipality directly managing the property and renting the apartments.\n\nA unique feature of Olympia is its internal bicycle storage.  Recognizing the importance of bicycles for workers and the potential for damage in the building's porches, Gratama incorporated this thoughtful solution.\n\nOver the years, Olympia has undergone significant renovations, most recently between 2010 and 2013.  These renovations aimed at improving energy efficiency and modernizing living conditions, while respecting the building's historical character.  Today, the majority of the units are still owned and managed by Ymere, a large housing corporation in the Netherlands. Some units have been sold to private individuals. The complex stands as a testament to Amsterdam's architectural heritage and its ongoing adaptation to the needs of its residents.\n"}
#
# Result ID: 5728327, Score: 0.6121657490730286
# Metadata: {'title': 'Weesperzijde 79D', 'main_category': 'building', 'subcategories': 'unique architecture, art', 'latitude': np.float64(52.35365555555556), 'longitude': np.float64(4.910872222222222), 'generated_text': 'This building at Weesperzijde 79D in Amsterdam East is a fascinating example of how urban development and architectural design can intertwine, sometimes quite dramatically.  Constructed in 2001, it\'s a relatively small building, a sort of “shoebox,” as its designers, MVRDV, described it. Commissioned by Thonik, the building\'s design was initially intended to be both residential and office space. However, local residents had concerns which meant it was eventually used solely as an office.\n\nDespite its compact size, the architects incorporated interesting relief into the design, most notably with the upward-sloping windows. The use of lightweight building blocks for both internal and external walls was a practical solution, given the building’s confined location.  The design even won the Amsterdam Art Prize.\n\nThe building initially featured a striking bright orange exterior, a bold choice by Thonik intended to create a warm impression.  However, this colour proved far too vibrant for the local residents,  who found it aggressive and even disruptive.  The ensuing dispute escalated into a legal battle, which eventually involved then-lawyer Eberhard van der Laan, who later became Amsterdam\'s mayor.\n\nThe legal battle ended with a compromise: the building was repainted in apple green, a calmer hue. This was a solution that satisfied both the residents and the architects.  The colour – according to MVRDV – was "not orange, but still bright".\n\nInterestingly, the building\'s apple-green colour ended up being the subject of another unusual debate a few years later.  A resident in Den Helder painted her house the same shade of apple green, only to find herself embroiled in a dispute with neighbours and local authorities over the colour. The case went all the way to the Council of State.\n\nSo, next time you pass this small but significant building, remember its colourful history, and the architectural and community considerations that helped shape it.\n'}
#
# Result ID: 5352964, Score: 0.6090295314788818
# Metadata: {'title': 'Linnaeusstraat 2C (Amsterdam)', 'main_category': 'building', 'subcategories': 'unique architecture, house', 'latitude': np.float64(52.36173333333333), 'longitude': np.float64(4.922658333333334), 'generated_text': 'This building at Linnaeusstraat 2C, in Amsterdam East, is a fascinating example of mid-20th-century architecture.  Standing next to the more classical Royal Tropical Institute (KIT) building, this ten-story tower, designed by Tjeerd Dijkstra and completed in 1967, offers a striking contrast.  Initially built as housing for international guests of the KIT, it featured six single and double rooms per floor, arranged around a central core.  The building’s low, single-story base subtly blends it into the surrounding Oosterpark. However, the most striking feature is its rooftop –  a high, surrounding border of corten steel, a relatively innovative material for the time.\n\nInitially used as a KIT guesthouse, it later became an NH Hotel branch.  In 2008, it was included in the Top 100 list of post-war architecture, though it did not achieve municipal or national monument status. Since 2015, it has been managed by the KIT once more, and is currently undergoing a significant renovation under the direction of architect Wiel Arets. This complete refurbishment will see it stripped down to its shell and given a new "crystalline skin", emphasizing sustainability and connecting it to the KIT\'s own cold-heat storage system. The renovated building will represent a commitment to a gas-free future and a revitalised space within the KIT campus.\n'}
#
# Result ID: 5634601, Score: 0.6022597551345825
# Metadata: {'title': 'Rijksmonument 335330', 'main_category': 'monument', 'subcategories': 'unique architecture, building', 'latitude': np.float64(52.34030833333333), 'longitude': np.float64(4.943938888888889), 'generated_text': 'This building complex, declared a national monument in 1988, is a fascinating example of Amsterdam School and Nieuwe Bouwen architectural styles.  Built between 1926 and 1928 by Dick Greiner, it originally served as a community center, fulfilling a role similar to that of a church in this Betondorp neighborhood.\n\nThe building\'s angular design is striking, featuring staggered windows and floors. Notice the cube-shaped keystone to the right of the entrance on Veeteeltstraat, flanking a small staircase. A deeply blue door sits to the left, with a 1927 cornerstone between it and the staircase.  A striking vertical window row curves ninety degrees into a horizontal one. These are set within large panels of grey, textured concrete. The three-story section boasts the largest window, a remarkable expanse of forty panes, supported by similar cube-shaped keystones.\n\nThe building features two and three-story sections, with a gallery on the northeast side.  From the Brink side, it presents a stair-step profile. The entrance on the Brink side, originally the main entrance, features a black and white tile tableau leading to a vibrant red door, typical of the Amsterdam School style.  The door displays the words "Volksgebouw" –  "Community Building" – in vertical lettering. A connecting gallery leads to the library.\n\nThe building\'s name, in gilded Amsterdam School lettering, was displayed on the Veeteeltstraat facade until at least 2004, although these were later removed or covered.  The building has housed various institutions over the years, including a house synagogue, evidenced by the nearby memorial stone for Jewish Betondorp residents. Today, it\'s home to the Stichting Shir Guru Ravidass Sabha.\n\nThe transition to the adjacent brick buildings on Veeteeltstraat, designed by Gerrit Versteeg, is quite abrupt. Finally, note the majestic horse chestnut tree in front of the entrance, planted around 1930.  This building is a testament to the architectural and social history of Amsterdam.\n'}
#
# Result ID: 802255, Score: 0.600511908531189
# Metadata: {'title': 'Watertoren (Boven-Hardinxveld)', 'main_category': 'monument', 'subcategories': 'unique architecture, building', 'latitude': np.float64(51.822500000000005), 'longitude': np.float64(4.87388888888889), 'generated_text': 'Welcome to this water tower, a fascinating example of early 20th-century architecture.  Constructed in 1923, it\'s a great illustration of the architectural trends of its time.  The design blends elements of the "Nieuwe Bouwen" style – a movement emphasizing functionalism and modern materials – with influences from the Amsterdam School, known for its expressive brickwork and robust forms. Notice the heavy roof; that\'s a characteristic feature linking it to the Amsterdam School.  The tower, built by the N.V. Algemeene Beton Compagnie from The Hague, stands tall at 42.9 meters and boasts a concrete reservoir with a capacity of 215 cubic meters. Its architectural and historical significance is recognized through its official designation as a national monument.  Take a moment to appreciate the blend of styles and the enduring presence of this impressive structure.\n'}
#
# Result ID: 4752682, Score: 0.5999965667724609
# Metadata: {'title': 'Plan Pampus', 'main_category': 'story', 'subcategories': 'city, trivia', 'latitude': np.float64(52.35854444444445), 'longitude': np.float64(5.039633333333334), 'generated_text': "Plan Pampus: A City That Never Was\n\nImagine Amsterdam, but vastly larger, extending eastward into the IJmeer lake. This wasn't a fanciful dream, but a concrete proposal, Plan Pampus, drawn up by the architectural firm of Jaap Bakema in 1964-1965.  The plan envisioned a sprawling archipelago of artificial islands, stretching beyond the island of Pampus, designed to house a staggering 350,000 people – a truly ambitious project.  \n\nThe post-war reconstruction of Amsterdam initially focused on rebuilding, not expansion. However, rising prosperity in the 1960s fueled a different vision of urban planning.  The increase in car ownership meant that people preferred living outside the old city centers.  The idea of a Central Business District emerged, where people would work in the city center, and live in more spacious, green suburban areas.  Many plans, including Plan Jokinen, looked at making the city more car-friendly.  Amsterdam would see the demolition of older neighborhoods, and the construction of modern office buildings.  Simultaneously, the creation of new residential areas in the newly reclaimed IJsselmeer polders was planned, and cities like Lelystad began to take shape.\n\nBakema’s Plan Pampus aimed to provide a new, affluent population with a modern living environment. The concept was a series of interconnected islands linked to the old city by a fourteen-lane highway and a monorail. The plan included a considerably smaller IJmeer lake than today’s.  High-rise residential towers would achieve a high population density. However, their placement around the water and the surrounding green areas would ensure they didn’t feel overly dense, in line with Le Corbusier’s ideas of towers in parks as an ideal living arrangement.\n\nUltimately, Plan Pampus was never realised.  The eastern part of the IJmeer lake and Pampus were not part of Amsterdam's territory but belonged to Muiden, requiring annexation.  More crucially, after lengthy negotiations, Amsterdam acquired the western part of Weesperkarspel in 1966, making the Bijlmermeer a much more cost-effective location for a new district.  Moreover, changing attitudes in the 1970s showed a preference for houses with gardens, leading to the development of suburban areas like Almere, contrasting with the high-rise concepts of Plan Pampus.  The proposed reclamation of the Markerwaard also never occurred, due to the influence of the growing environmental movement.\n\nWhile Plan Pampus remained unrealized, its influence can still be seen.  IJburg, built in a similar location, could be described as a smaller, less dense version of Bakema's vision. It shows a diluted echo of Plan Pampus.  However, recent high-rise construction projects in Zeeburg are revisiting the idea of tower blocks.   The echoes of Bakema’s ambitious plan continue to shape Amsterdam's development to this day.\n"}
#
# Result ID: 5906625, Score: 0.5970782041549683
# Metadata: {'title': 'Utrechtsedwarsstraat 6-8', 'main_category': 'building', 'subcategories': 'unique architecture, street', 'latitude': np.float64(52.360905555555554), 'longitude': np.float64(4.896661111111111), 'generated_text': "This building at 6-8 Utrechtsedwarsstraat is a striking example of Amsterdam architecture.  It’s located in a section of the street between Reguliersgracht and Utrechtsestraat, an area that has seen significant changes over the years.  The street itself is linked to the Utrechtsestraat, the historic route from Amsterdam to Utrecht.  \n\nOur building, constructed in 1935, has a fascinating history.  It was commissioned by a garage owner, J.J. van Breda, who owned several plots of land here and on the adjacent Falckstraat.  He wanted to modernize his property and employed architect Cornelis Kruyswijk, who lived nearby.  Tragically, Kruyswijk died just before the building's completion.\n\nThe building stands out because of its modern design, contrasting sharply with the adjacent warehouse-like structures.  These neighboring buildings lean slightly forward, a common feature to create more space between goods and the façade, while this building stands perfectly upright.  Its most distinctive feature is a three-story bay window – a rare sight on this street.\n\nThe building's design is notable for its clean lines, a restrained use of natural stone, and a subtle nod to the Amsterdam School style, particularly visible in a small, cube-shaped stone element below the bay window.  The combination of brick, wood, and stone creates a visually appealing structure.  The building has a ground floor storage area, which was originally intended as a garage, and three floors of residential units. The building’s height allows for substantial blind surfaces on both sides, given it is taller than its neighbors. Its design stands out, even against the changing backdrop of Amsterdam's cityscape.  It is now a municipal monument, a testament to its unique architectural merits.\n"}
#
# Result ID: 4408827, Score: 0.596351146697998
# Metadata: {'title': 'Stadhouderskade 40-41', 'main_category': 'house', 'subcategories': 'unique architecture, garden', 'latitude': np.float64(52.36101111111111), 'longitude': np.float64(4.884311111111111), 'generated_text': "Welcome to number 40-41 Stadhouderskade.  This impressive building, located in Amsterdam's Museum Quarter, is actually a double villa, a striking example of eclectic architecture.  Notice the blend of architectural styles; you can see clear influences of classicism and the Louis XVI style.\n\nTake a moment to appreciate the ornate detailing on the façade.  The balconies, pilasters, and friezes are all meticulously crafted.  Almost the entire building is covered in plasterwork, which contributes to its elegant appearance.  It's also quite unique for this location:  one of the few buildings on the Stadhouderskade to boast a small front garden and a forecourt.\n\nInterestingly, one of the neighboring buildings also holds a significant historical status, and directly across the street, the Stadhouderskade continues at number 42 – the former address of the Rijksmuseum.  This gives you a sense of the area's rich history and how this building fits into its larger context.\n"}
#
# Result ID: 5395888, Score: 0.5954350233078003
# Metadata: {'title': 'Nieuwe Looiersstraat 68-70', 'main_category': 'building', 'subcategories': 'unique architecture, street', 'latitude': np.float64(52.360575), 'longitude': np.float64(4.892697222222222), 'generated_text': 'We\'re standing before a building at 68-70 Nieuwe Looiersstraat, a fascinating example of architectural blending in Amsterdam.  Built around 1940, this structure stands as a testament to the city\'s ever-evolving cityscape.  The street itself is a fascinating mix of styles, reflecting the layers of history that have shaped Amsterdam.  \n\nThis particular building, designed by architects Pieter Rinze Bloemsma and Justus Hendrik Scheerboom, isn\'t exceptionally unique in its style – it reflects the principles of the "New Building" movement.  However, its significance lies in its context:  its modern design stands out strikingly amidst the predominantly 19th-century architecture of the surrounding canal ring.  Notice the tiled entranceway, the clean, rectangular form, and the integrated storage areas.\n\nWhat\'s truly special, however, isn\'t immediately visible from the street.  Several houses on Nieuwe Looiersstraat, including this one, are connected to buildings on the adjacent Fokke Simonszstraat. In fact, its counterpart at number 27-29 Fokke Simonszstraat features a similar design, though with a slightly lower entrance.  This pair of buildings gained municipal monument status in November 2006, a recognition of their architectural and historical importance to Amsterdam.  Interestingly, the building on Fokke Simonszstraat even has a foundation stone embedded in its facade.  These seemingly ordinary buildings, therefore, offer a remarkable glimpse into Amsterdam’s complex urban development and architectural evolution.\n'}
#
# Result ID: 2829213, Score: 0.59466153383255
# Metadata: {'title': 'Wilhelminakerk (Utrecht)', 'main_category': 'church', 'subcategories': 'unique architecture, monument', 'latitude': np.float64(52.083688888888894), 'longitude': np.float64(5.143216666666667), 'generated_text': "Welcome to the Wilhelminakerk, a beautiful example of Amsterdam School architecture.  This church, located in Utrecht's Schildersbuurt, was constructed around 1931.  Notice the distinctive features of the Amsterdam School style – you'll see it in the building's robust lines and the expressive use of brickwork. The architect, H.F. Mertens, created a truly unique structure. Its significance is reflected in its designation as a municipal monument, a testament to its enduring architectural and cultural value.  The building stands proudly at the corner of Hobbemastraat and Paulus Potterstraat, a striking presence in this charming neighborhood.  Take a moment to appreciate the details of the facade, the textures, and the overall design.  It’s a truly rewarding sight for architecture enthusiasts and casual visitors alike.\n"}
#
# Result ID: 5668803, Score: 0.5941929817199707
# Metadata: {'title': 'Van der Helstplein 7-17', 'main_category': 'unique architecture', 'subcategories': 'monument, building', 'latitude': np.float64(52.35165555555556), 'longitude': np.float64(4.895202777777778), 'generated_text': 'This building complex at Van der Helstplein 7-17 in Amsterdam South is a fascinating example of early Amsterdam School architecture.  Designated a national monument in 2004, its history stretches back to the early 20th century, a time when Amsterdam was expanding its urban planning.\n\nOriginally designed in 1916 by the renowned architect Piet Kramer, construction was delayed by World War I material shortages.  Finally completed in 1919 and 1920, the building showcases Kramer\'s signature style, although perhaps less exuberant than some of his other works.  Notice the symmetrical design, with a long façade facing the square and two perpendicular sections extending into the adjacent streets.\n\nObserve the characteristic blend of natural stone and brick, the saw-tooth patterns on the corners, the wooden balcony railings, and the stylish rooflines. The windows themselves are a key feature, with their prominent sidelights, often referred to as "trapjes" or little stairs, and the uniquely placed window sections at the junctions of the building\'s different parts.  The vertical zigzag brickwork further emphasizes these divisions. \n\nLook closely at the distinctive dark blue and red trim separating the shops from the residences, and the matching doors, which maintain their original detailing, even after renovations.  These small details, including the  decorative elements, are not merely aesthetic; they cleverly conceal the attic spaces, as noted by architectural writer Jaap Huisman. He described the square and its buildings as having a "Parisian atmosphere" in a 1994 article.\n\n\nThe building\'s significance extends beyond its architectural merit.  It\'s considered a crucial early work within Kramer\'s portfolio, demonstrating his distinct approach to designing both long and short sides of a building block.  Furthermore, seven trees in front of the building, dating back to the construction period, have also been designated as monumental greenery by the city.  The complex stands as a testament to a significant period in Amsterdam\'s architectural and urban development.\n'}
#
# Result ID: 5591758, Score: 0.5936171412467957
# Metadata: {'title': 'Bureau Europa', 'main_category': 'museum', 'subcategories': 'art, architecture', 'latitude': np.float64(50.85670555555556), 'longitude': np.float64(5.690497222222223), 'generated_text': 'Bureau Europa: A Platform for Architecture and Design\n\nBureau Europa, formerly known as NAi Maastricht, is a platform dedicated to architecture, urban planning, and design, situated in the heart of Maastricht.  Established in 2006 as an offshoot of the Netherlands Architecture Institute (NAi) in Rotterdam, it initially occupied a section of the historic Wiebengahal, a beautiful example of the "New Building" style. This location, nestled amongst other cultural institutions, created a vibrant museum district.\n\nOne of the key figures in Bureau Europa’s early years was Guus Beumer. His vision significantly shaped the institution’s trajectory. In 2009, NAi Maastricht gained its independence, becoming NAiM / Bureau Europa, and later simply Bureau Europa.  A move to the Sphinxkwartier in 2013 brought them to a former factory, offering a unique industrial setting.  A significant renovation in 2018 temporarily closed the building, but it reopened with a renewed vigor. Now, Bureau Europa also utilizes storefront spaces, showcasing current exhibitions and local artistic talents.\n\nBureau Europa’s mission is to foster knowledge and cultivate talent within the cultural sphere, focusing particularly on the shared social agenda of Europe and the Meuse-Rhine Euregion. They achieve this through various projects, including exhibitions, lectures, workshops, and city tours—all revolving around architecture, urban planning, and design.  The aim is to stimulate critical analysis of the built environment, encouraging new narratives about our cities and their development.\n\nOver the years, Bureau Europa has hosted a wide range of exhibitions and projects, exploring diverse themes in architecture and design.  From early shows focusing on new faces in European architecture and the works of prominent figures like P.J.H. Cuypers, to explorations of contemporary issues such as sustainability and social innovation,  the exhibitions reflect an ongoing dialogue on the past, present, and future of design and its impact on society. Recent exhibitions have further broadened the scope, encompassing topics such as the history of Maastricht\'s ceramic industry and the role of design in healthcare. The program consistently reflects a commitment to fostering dialogue and understanding across various disciplines and societal concerns.\n'}
#
# Result ID: 5431726, Score: 0.5933233499526978
# Metadata: {'title': 'Dijsselhofplantsoen 10', 'main_category': 'house', 'subcategories': 'unique architecture, monument', 'latitude': np.float64(52.35148888888889), 'longitude': np.float64(4.875419444444445), 'generated_text': 'This building at number 10 Dijsselhofplantsoen is a remarkable example of restrained Amsterdam School architecture.  Built in 1928 and 1929 for a tobacco merchant, B.A. Sanders, it\'s a testament to the architectural style prevalent in the area at the time.  The architect, Gerrit Jan Rutgers, designed several buildings on this street, all reflecting a similar aesthetic.\n\nThe villa, rectangular in plan, boasts a basement, ground floor, first floor, attic, and a small loft. The exterior walls are constructed in Flemish bond, a traditional bricklaying pattern.  Interestingly, a rear extension connecting it to number 12 provides access to various storage areas. Number 12 itself was designed by another prominent Amsterdam School architect, Piet Kramer, showcasing the consistent architectural vision along this street.\n\nFor many years, the villa was known as "La Pergola," after a pergola that once graced its grounds.  The pergola is long gone, but the villa itself was declared a national monument in December 2004.  Its designation recognizes the building’s architectural and cultural historical significance. Its sober expressionist style makes it a defining feature of the street\'s villa landscape, in fact it\'s the only monument on this street.\n\nLook closely at the facade. You\'ll notice three striking carved stone features. Two bird sculptures flank a window, a detail echoed in a similar design at number 6 on this street. Above the entrance, a larger stone depicts two seated figures –  Mr. and Mrs. Sanders – framed by the names of their children, Bram and Maria, although parts of these names are now eroded. The artist of these lovely features is currently unknown.\n\nA notable resident of the villa was Cor van Zadelhoff, who lived here from 1974 to 1978. This beautiful building offers a captivating glimpse into Amsterdam’s architectural heritage and the lives of those who once called it home.\n'}
#
# Result ID: 5679631, Score: 0.5929728746414185
# Metadata: {'title': 'Lycka', 'main_category': 'building', 'subcategories': 'unique architecture,  sustainable technology', 'latitude': np.float64(52.38633611111111), 'longitude': np.float64(4.837416666666666), 'generated_text': 'Let\'s explore Lycka, a striking building in Amsterdam Nieuw-West.  Standing fifty meters tall, it\'s a fascinating blend of workspace and social housing.  The apartments are diverse, each type boasting a unique architectural style, varying in materials and color. This creates a visual effect of five stacked residential blocks, each with its own distinct personality.  A shared central core houses amenities including an indoor bicycle storage area.\n\nSustainability is a key feature.  Lycka incorporates water retention systems, solar panels, and district heating, while boasting a communal rooftop garden and is entirely gas-free.  It\'s a testament to modern, eco-conscious design.  \n\nThis building, constructed by Hillen & Roosen for the housing corporation Eigen Haard, was designed by “Team Paul de Vroom + Sputnik”. Its creation is part of a larger urban renewal project transforming the unfinished Amsterdam Teleport office park into the mixed residential and commercial area of Sloterdijk-Centrum.  \n\nInterestingly, the building\'s location and name have an intriguing backstory. Originally planned for streets named after European airports – Luton, Zaventem, and Arlanda – a change in plans resulted in the creation of a courtyard instead of a street.  The street name was thus changed to Lutonhof before construction in 2018.  The building itself, a playful nod to its proximity to the former Arlandaweg, was named Lycka, the Swedish word for "happiness" – a fitting title for this innovative and sustainable structure.  \n\nAnd in recognition of its innovative design, Lycka was nominated for the Amsterdam New Construction Prize in 2022.\n'}
#
# Result ID: 5696404, Score: 0.5926494002342224
# Metadata: {'title': 'Prins Hendrikkade 600', 'main_category': 'building', 'subcategories': 'unique architecture, museum', 'latitude': np.float64(52.37145), 'longitude': np.float64(4.912647222222223), 'generated_text': 'This building at 600 Prins Hendrikkade, Amsterdam, has a fascinating history. Initially, a pavilion designed by Renzo Piano was constructed here in 1996 to offer views of his creation, the NEMO Science Museum.  This pavilion, situated on the Oosterdok quay where the Schippersgracht canal meets the main waterway, eventually needed repurposing.\n\nThe Architectuurcentrum Amsterdam (ARCAM), previously located in a smaller space, required larger premises. The solution involved expanding and transforming the existing pavilion. The design had to meet several strict requirements: seamlessly integrate with the original structure while retaining existing floors and columns; avoid disrupting the Prins Hendrikkade façade when viewed from the Maritime Museum, necessitating a lower waterfront façade and a taller street-facing one; and present a unified façade when viewed from the Prins Hendrikkade.  The desired result was a monolithic structure, minimizing any projections or extensions.\n\nArchitect René van Zuuk’s design successfully met these challenges. The resulting three-story building has a trapezoidal footprint with a section cut off. The structure features continuous Kalzip (aluminum and zinc) cladding, forming a unified roof and wall system that covers most of the building’s exterior.  However, the waterside façade is made of glass within metal frames, while the street-side façade combines Kalzip and glass.  These glass sections provide glimpses into the interior\'s organization, featuring open spaces around a central core containing stairs, elevators, and restrooms.  The internal layout intriguingly mixes rounded and angular elements.\n\nCompleted in 2003 for the Amsterdam Municipal Housing Service, after four years of work, the building’s official opening took place on October 24th, 2003. The first exhibition fittingly titled "Open Due to Renovation", reflects the building\'s unique transformation. A small information panel on the main façade, by the architect himself, describes the building as a blend of architecture and ornamentation.  It’s a testament to innovative design solutions within the constraints of a historic urban setting.\n'}
#
# Result ID: 5584147, Score: 0.5923590660095215
# Metadata: {'title': 'Jan Evertsenstraat 1 (Amsterdam)', 'main_category': 'building', 'subcategories': 'unique architecture, house', 'latitude': np.float64(52.37132777777778), 'longitude': np.float64(4.859455555555555), 'generated_text': 'This building at Jan Evertsenstraat 1, in Amsterdam, is a unique example of early 20th-century architecture. While it has an address on Jan Evertsenstraat, its physical location is somewhat isolated from the other buildings on that street.  It’s nestled amongst buildings on other streets, yet shares a similar architectural style with them.\n\nThe building complex was constructed around 1912, a time when this area belonged to the municipality of Sloten, although Amsterdam was already asserting its influence.  Sloten constructed a road branching off from the Admiraal de Ruijterweg, creating a sharp bend in the road, and planned for side streets, resulting in the intersection now known as De Krommert. This intersection features two adjacent southward-facing T-junctions with a northward-facing T-junction in between.\n\nThe construction company, De Driesprong, owned by Vonk and Balke, was granted permission by Sloten to build on the land between the two southward branches of the intersection.  Interestingly, the addresses of the buildings in this complex all refer to prominent Dutch admirals: Van Speijkstraat 175-179, Admiraal de Ruijterweg 79-83, Jan Evertsenstraat 1, and Witte de Withstraat 182-188.\n\nThe building\'s architectural style deviates from the prevailing Amsterdam School style prevalent in the surrounding area. Although the architects of neighbouring buildings, Cornelis Kruyswijk, Jouke Zietsma, and Jo van der Mey, were all proponents of the Amsterdam School, Vonk and Balke chose a different approach.  Their building features four floors and a roof with several asymmetrical dormer windows. The facade is characterized by a striking contrast between large windows with relieving arches and smaller rectangular windows.  An unusual feature is the white plastered strip under the eaves,  while the wainscoting of the ground floor shops,  heavy rectangular, rounded wooden constructions, likely added during renovations in the 1920s and 30s, and the natural stone base are typical of the Amsterdam School.\n\nDespite its unique characteristics, the building complex is classified by the municipality as "Orde 2," meaning it\'s almost, but not quite, a designated monument.  It remains a fascinating example of a building that straddles different architectural styles and historical periods.\n'}
#
# Result ID: 1010188, Score: 0.5921813249588013
# Metadata: {'title': 'Gouden Leeuw (Amsterdam)', 'main_category': 'unique architecture', 'subcategories': 'building, neighbourhood', 'latitude': np.float64(52.32436944444445), 'longitude': np.float64(4.974458333333334), 'generated_text': "This apartment complex, Gouden Leeuw, located in Amsterdam-Zuidoost, is more than just a place to live; it's a testament to innovative architectural design and community living.  Built around 1974, the complex stands out for its unique design by architect Joop van Stigt.  Instead of the typical, often honeycomb-like, apartment blocks common at the time, Van Stigt opted for a cross-shaped structure, creating a series of interconnected buildings that maximized space and light.  His design, categorized as structuralist, uses a system of repeating square units, each a multiple of 2.5 meters – a dimension meant to evoke a sense of human scale and comfort.  These units are remarkably flexible, with removable internal walls.\n\nThe architect envisioned a space where communal living thrived.  This is reflected in the inclusion of shared spaces such as a café, a dance hall, and small shops.  These communal areas, originally found in many Bijlmer flats, are now rare, with Gouden Leeuw and its sister complex, Groenhoven, being among the few to retain them.  The covered walkways connecting the buildings and the parking garage also demonstrate this focus on community, creating safe and convenient passageways unlike many other developments in the area.  Interestingly, these flats were sold to individual owners, forming one of the largest owner’s associations in the Netherlands, rather than being managed by a housing corporation.  The innovative design and approach to communal living led to its inclusion in the Top 100 list of post-war heritage in 2008, and later, in 2021, the entire complex, including its surrounding park, was officially designated a municipal monument.  The unique arrangement of the buildings within the park setting was pivotal in this recognition.\n"}
